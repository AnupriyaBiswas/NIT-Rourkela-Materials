# %%
# Import required packages
import numpy as np
import pandas as pd
import os
import warnings
warnings.filterwarnings("ignore")

# %%
from keras.models import Sequential
from keras.layers import Dense,Flatten,LSTM, GRU,Bidirectional,TimeDistributed
from keras.callbacks import ModelCheckpoint,EarlyStopping
from keras.metrics import RootMeanSquaredError,mean_absolute_percentage_error
from keras.losses import MeanSquaredError
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Dropout

# %%
# split a univariate time series into patterns
def get_Patterns(TSeries, n_inputs,h):
    X,y,z = pd.DataFrame(np.zeros((len(TSeries)-n_inputs-h+1,n_inputs))), pd.DataFrame(), pd.DataFrame()
    for i in range(len(TSeries)):
        # find the end of this pattern
        end_ix = i + n_inputs + h - 1
        # check if we are beyond the time series
        if end_ix > len(TSeries)-1:
            break
        # gather input and output parts of the pattern
        for j in range(n_inputs):
            X.loc[i,j]=TSeries.iloc[i+j,0]
        i=i+n_inputs
        #y=y.append(TSeries.iloc[end_ix], ignore_index = True)
        y=pd.concat([y, TSeries.iloc[end_ix]], ignore_index=True)
    return pd.DataFrame(X),pd.DataFrame(y)

# %%
# originalData should be a Column Vectored DataFrame
def minmaxNorm(originalData, lenTrainValidation):
    # Maximum Value
    max2norm=max(originalData.iloc[0:lenTrainValidation,0])
    # Minimum Value
    min2norm=min(originalData.iloc[0:lenTrainValidation,0])
    lenOriginal=len(originalData)
    normalizedData=np.zeros(lenOriginal)   
    normalizedData = []
    #Normalize using Min-Max Normalization
    for i in range (lenOriginal):
        normalizedData.append((originalData.iloc[i]-min2norm)/(max2norm-min2norm))    
    return pd.DataFrame(normalizedData)

# %%
# originalData and forecastedData should be Column Vectored DataFrames
def minmaxDeNorm( originalData, forecastedData, lenTrainValidation):
    # Maximum Value
    max2norm=max(originalData.iloc[0:lenTrainValidation,0])
    # Minimum Value
    min2norm=min(originalData.iloc[0:lenTrainValidation,0])
    lenOriginal=len(originalData)
    denormalizedData=[]   
    #De-Normalize using Min-Max Normalization
    for i in range (lenOriginal):
        denormalizedData.append((forecastedData.iloc[i]*(max2norm-min2norm))+min2norm)  
    return pd.DataFrame(denormalizedData)

# %%
# Timeseries_Data and forecasted_value should be Column Vectored DataFrames
def findRMSE( Timeseries_Data, forecasted_value,lenTrainValidation):
    l=Timeseries_Data.shape[0]
    lenTest=l-lenTrainValidation
    trainRMSE=0;
    for i in range (lenTrainValidation):
        trainRMSE=trainRMSE+np.power((forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0]),2) 
    trainRMSE=np.sqrt(trainRMSE/lenTrainValidation)

    testRMSE=0;
    for i in range (lenTrainValidation,l,1):
        testRMSE=testRMSE+np.power((forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0]),2)
    testRMSE=np.sqrt(testRMSE/lenTest)
    return trainRMSE, testRMSE

# %%
# Timeseries_Data and forecasted_value should be Column Vectored DataFrames
def findMAE( Timeseries_Data, forecasted_value,lenTrainValidation):
    l=Timeseries_Data.shape[0]
    lenTest=l-lenTrainValidation
    trainMAE=0;
    for i in range (lenTrainValidation):
        trainMAE=trainMAE+np.abs(forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0]) 
    trainMAE=(trainMAE/(lenTrainValidation));

    testMAE=0;
    for i in range (lenTrainValidation,l,1):
        testMAE=testMAE+np.abs(forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0])
    testMAE=(testMAE/lenTest);
    return trainMAE, testMAE

# %%
def Find_Fitness_LSTM(x,y,lenValid,lenTest):
    NOP=len(y)
    n_features=1
    lenTrain=NOP-lenValid-lenTest
    xTrain=x.iloc[0:lenTrain,:]
    xValid=x.iloc[lenTrain:(lenTrain+lenValid),:]
    xTest=x.iloc[(lenTrain+lenValid):NOP,:]
    yTrain=y.iloc[0:lenTrain,0]
    yValid=y.iloc[lenTrain:(lenTrain+lenValid),0]
    yTest=y.iloc[(lenTrain+lenValid):NOP,0]
    model1 = Sequential()
    model1.add(LSTM(256, activation='relu', input_shape=(LagLength,n_features)))
    model1.add(Flatten())
    model1.add(Dense(128, activation='relu'))
    model1.add(Dense(64, activation='relu'))
    model1.add(Dense(32, activation='relu'))
    model1.add(Dense(1,activation='linear'))
    checkpoint_filepath = '/cp.keras'
    cp1=ModelCheckpoint(checkpoint_filepath,save_best_only='True')
    model1.compile(loss=MeanSquaredError(),optimizer=Adam(learning_rate=0.01),metrics=[RootMeanSquaredError(),mean_absolute_percentage_error])
    # fit
    model1.fit(xTrain, yTrain,validation_data=(xValid,yValid), epochs=50, verbose=1)
    yhatNorm=model1.predict(x).flatten().reshape(x.shape[0],1)
    return pd.DataFrame(yhatNorm)

# %%
#Read the Time Series Dataset
Timeseries_Data=pd.read_csv('AQI.csv',header=None)
LagLength=24
h=1
lt=Timeseries_Data.shape[0]
lenTrain=int(round(lt*0.7))
lenValidation=int(round(lt*0.15))
lenTest=int(lt-lenTrain-lenValidation)
# NORMALIZE THE DATA
normalizedData=minmaxNorm(Timeseries_Data,lenTrain+lenValidation);
# Transform the Time Series into Patterns Using Sliding Window
X, y = get_Patterns(normalizedData, LagLength, h)
name='LSTM'
file1='./'+str(name)+"_Accuracy.xlsx"
file2='./'+str(name)+"_Forecasts.xlsx"
Forecasts=pd.DataFrame()
Accuracy=pd.DataFrame()

ynorm1=Find_Fitness_LSTM(X,y,lenValidation,lenTest) 
ynorm=pd.DataFrame(normalizedData.iloc[0:(LagLength+h-1),0])
ynorm=pd.concat([ynorm, ynorm1], ignore_index=True)
yhat=minmaxDeNorm(Timeseries_Data, ynorm, lenTrain+lenValidation)
Accuracy.loc[0,0],Accuracy.loc[0,1]=findRMSE( Timeseries_Data,yhat,lenTrain+lenValidation)
Accuracy.loc[0,2],Accuracy.loc[0,3]=findMAE( Timeseries_Data,yhat,lenTrain+lenValidation)
Forecasts=pd.concat([Forecasts, yhat.T], ignore_index=True)
Accuracy.to_excel(file1,sheet_name='Accuracy',index=False)
Forecasts.to_excel(file2,sheet_name='Forecasts',index=False)
print(Accuracy)
# Out:
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 139ms/step - loss: 0.1115 - mean_absolute_percentage_error: 2575011.7500 - root_mean_squared_error: 0.3295 - val_loss: 0.0011 - val_mean_absolute_percentage_error: 4.8959 - val_root_mean_squared_error: 0.0336
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.0130 - mean_absolute_percentage_error: 1230390.5000 - root_mean_squared_error: 0.1138 - val_loss: 0.0156 - val_mean_absolute_percentage_error: 26.1272 - val_root_mean_squared_error: 0.1248
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0176 - mean_absolute_percentage_error: 261556.1875 - root_mean_squared_error: 0.1322 - val_loss: 0.0016 - val_mean_absolute_percentage_error: 6.2252 - val_root_mean_squared_error: 0.0404
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.0074 - mean_absolute_percentage_error: 1521729.3750 - root_mean_squared_error: 0.0856 - val_loss: 6.7040e-04 - val_mean_absolute_percentage_error: 4.5234 - val_root_mean_squared_error: 0.0259
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.0027 - mean_absolute_percentage_error: 234856.7500 - root_mean_squared_error: 0.0513 - val_loss: 0.0012 - val_mean_absolute_percentage_error: 6.3148 - val_root_mean_squared_error: 0.0348
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.0016 - mean_absolute_percentage_error: 30077.0879 - root_mean_squared_error: 0.0400 - val_loss: 0.0011 - val_mean_absolute_percentage_error: 6.0575 - val_root_mean_squared_error: 0.0327
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 0.0017 - mean_absolute_percentage_error: 11220.4404 - root_mean_squared_error: 0.0417 - val_loss: 7.4792e-04 - val_mean_absolute_percentage_error: 4.9214 - val_root_mean_squared_error: 0.0273
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.0015 - mean_absolute_percentage_error: 21638.3027 - root_mean_squared_error: 0.0383 - val_loss: 0.0012 - val_mean_absolute_percentage_error: 6.5677 - val_root_mean_squared_error: 0.0347
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0015 - mean_absolute_percentage_error: 58174.5391 - root_mean_squared_error: 0.0385 - val_loss: 0.0017 - val_mean_absolute_percentage_error: 8.1648 - val_root_mean_squared_error: 0.0411
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.0013 - mean_absolute_percentage_error: 17696.8887 - root_mean_squared_error: 0.0364 - val_loss: 0.0011 - val_mean_absolute_percentage_error: 6.1738 - val_root_mean_squared_error: 0.0329
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 7.9989e-04 - mean_absolute_percentage_error: 28044.8145 - root_mean_squared_error: 0.0282 - val_loss: 7.1135e-04 - val_mean_absolute_percentage_error: 4.7756 - val_root_mean_squared_error: 0.0267
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0012 - mean_absolute_percentage_error: 50869.5156 - root_mean_squared_error: 0.0341 - val_loss: 6.0243e-04 - val_mean_absolute_percentage_error: 3.8392 - val_root_mean_squared_error: 0.0245
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 7.9857e-04 - mean_absolute_percentage_error: 48266.2617 - root_mean_squared_error: 0.0282 - val_loss: 3.8592e-04 - val_mean_absolute_percentage_error: 2.2349 - val_root_mean_squared_error: 0.0196
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 4.5097e-04 - mean_absolute_percentage_error: 33012.9570 - root_mean_squared_error: 0.0212 - val_loss: 3.9141e-04 - val_mean_absolute_percentage_error: 2.1874 - val_root_mean_squared_error: 0.0198
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 4.7010e-04 - mean_absolute_percentage_error: 11436.6494 - root_mean_squared_error: 0.0215 - val_loss: 4.4816e-04 - val_mean_absolute_percentage_error: 2.4378 - val_root_mean_squared_error: 0.0212
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 4.2542e-04 - mean_absolute_percentage_error: 117953.4297 - root_mean_squared_error: 0.0206 - val_loss: 5.1854e-04 - val_mean_absolute_percentage_error: 3.1250 - val_root_mean_squared_error: 0.0228
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 4.9844e-04 - mean_absolute_percentage_error: 403359.2500 - root_mean_squared_error: 0.0223 - val_loss: 5.3803e-04 - val_mean_absolute_percentage_error: 3.4744 - val_root_mean_squared_error: 0.0232
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 4.5034e-04 - mean_absolute_percentage_error: 88629.6875 - root_mean_squared_error: 0.0212 - val_loss: 3.6908e-04 - val_mean_absolute_percentage_error: 2.2148 - val_root_mean_squared_error: 0.0192
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 3.7122e-04 - mean_absolute_percentage_error: 74027.3047 - root_mean_squared_error: 0.0190 - val_loss: 4.1742e-04 - val_mean_absolute_percentage_error: 2.5432 - val_root_mean_squared_error: 0.0204
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 3.4929e-04 - mean_absolute_percentage_error: 196317.4062 - root_mean_squared_error: 0.0187 - val_loss: 4.1904e-04 - val_mean_absolute_percentage_error: 3.0226 - val_root_mean_squared_error: 0.0205
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 3.5878e-04 - mean_absolute_percentage_error: 141635.3906 - root_mean_squared_error: 0.0187 - val_loss: 4.2163e-04 - val_mean_absolute_percentage_error: 2.3461 - val_root_mean_squared_error: 0.0205
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 3.6072e-04 - mean_absolute_percentage_error: 260111.5000 - root_mean_squared_error: 0.0189 - val_loss: 4.0687e-04 - val_mean_absolute_percentage_error: 2.8886 - val_root_mean_squared_error: 0.0202
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 4.1302e-04 - mean_absolute_percentage_error: 19386.5352 - root_mean_squared_error: 0.0203 - val_loss: 3.4597e-04 - val_mean_absolute_percentage_error: 2.0265 - val_root_mean_squared_error: 0.0186
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 2.1878e-04 - mean_absolute_percentage_error: 89969.6406 - root_mean_squared_error: 0.0147 - val_loss: 5.1875e-04 - val_mean_absolute_percentage_error: 3.2654 - val_root_mean_squared_error: 0.0228
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 3.4173e-04 - mean_absolute_percentage_error: 141204.3906 - root_mean_squared_error: 0.0184 - val_loss: 3.3936e-04 - val_mean_absolute_percentage_error: 2.0700 - val_root_mean_squared_error: 0.0184
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 3.1865e-04 - mean_absolute_percentage_error: 87785.5391 - root_mean_squared_error: 0.0178 - val_loss: 3.8008e-04 - val_mean_absolute_percentage_error: 2.2199 - val_root_mean_squared_error: 0.0195
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 2.9981e-04 - mean_absolute_percentage_error: 101318.3906 - root_mean_squared_error: 0.0172 - val_loss: 3.6336e-04 - val_mean_absolute_percentage_error: 2.1768 - val_root_mean_squared_error: 0.0191
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 2.6434e-04 - mean_absolute_percentage_error: 60602.0586 - root_mean_squared_error: 0.0160 - val_loss: 4.1608e-04 - val_mean_absolute_percentage_error: 2.7513 - val_root_mean_squared_error: 0.0204
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 4.8877e-04 - mean_absolute_percentage_error: 193962.1406 - root_mean_squared_error: 0.0220 - val_loss: 5.5268e-04 - val_mean_absolute_percentage_error: 3.9630 - val_root_mean_squared_error: 0.0235
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 5.2142e-04 - mean_absolute_percentage_error: 235487.5156 - root_mean_squared_error: 0.0228 - val_loss: 6.6494e-04 - val_mean_absolute_percentage_error: 4.2977 - val_root_mean_squared_error: 0.0258
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 3.4153e-04 - mean_absolute_percentage_error: 10048.9844 - root_mean_squared_error: 0.0184 - val_loss: 3.8000e-04 - val_mean_absolute_percentage_error: 2.5185 - val_root_mean_squared_error: 0.0195
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 2.6391e-04 - mean_absolute_percentage_error: 67928.6172 - root_mean_squared_error: 0.0162 - val_loss: 3.5030e-04 - val_mean_absolute_percentage_error: 2.1158 - val_root_mean_squared_error: 0.0187
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 2.4733e-04 - mean_absolute_percentage_error: 41631.2266 - root_mean_squared_error: 0.0156 - val_loss: 4.4746e-04 - val_mean_absolute_percentage_error: 3.2533 - val_root_mean_squared_error: 0.0212
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 3.4421e-04 - mean_absolute_percentage_error: 15014.0703 - root_mean_squared_error: 0.0185 - val_loss: 5.9615e-04 - val_mean_absolute_percentage_error: 4.0357 - val_root_mean_squared_error: 0.0244
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 3.6077e-04 - mean_absolute_percentage_error: 146498.9375 - root_mean_squared_error: 0.0189 - val_loss: 3.4922e-04 - val_mean_absolute_percentage_error: 2.1267 - val_root_mean_squared_error: 0.0187
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 4.6566e-04 - mean_absolute_percentage_error: 34267.0586 - root_mean_squared_error: 0.0213 - val_loss: 2.9888e-04 - val_mean_absolute_percentage_error: 1.9362 - val_root_mean_squared_error: 0.0173
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 2.6047e-04 - mean_absolute_percentage_error: 23130.7637 - root_mean_squared_error: 0.0159 - val_loss: 3.7766e-04 - val_mean_absolute_percentage_error: 2.3077 - val_root_mean_squared_error: 0.0194
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 3.3512e-04 - mean_absolute_percentage_error: 265448.5312 - root_mean_squared_error: 0.0182 - val_loss: 0.0011 - val_mean_absolute_percentage_error: 6.3036 - val_root_mean_squared_error: 0.0336
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 5.9051e-04 - mean_absolute_percentage_error: 53838.3281 - root_mean_squared_error: 0.0242 - val_loss: 4.1118e-04 - val_mean_absolute_percentage_error: 3.0993 - val_root_mean_squared_error: 0.0203
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 4.7721e-04 - mean_absolute_percentage_error: 30489.0508 - root_mean_squared_error: 0.0217 - val_loss: 0.0010 - val_mean_absolute_percentage_error: 5.9483 - val_root_mean_squared_error: 0.0319
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 8.1532e-04 - mean_absolute_percentage_error: 340547.4062 - root_mean_squared_error: 0.0283 - val_loss: 4.6481e-04 - val_mean_absolute_percentage_error: 3.5180 - val_root_mean_squared_error: 0.0216
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 4.1468e-04 - mean_absolute_percentage_error: 99620.8984 - root_mean_squared_error: 0.0203 - val_loss: 6.0769e-04 - val_mean_absolute_percentage_error: 4.3617 - val_root_mean_squared_error: 0.0247
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 4.7503e-04 - mean_absolute_percentage_error: 64897.6680 - root_mean_squared_error: 0.0216 - val_loss: 0.0011 - val_mean_absolute_percentage_error: 6.3100 - val_root_mean_squared_error: 0.0337
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 7.2834e-04 - mean_absolute_percentage_error: 34269.1172 - root_mean_squared_error: 0.0270 - val_loss: 3.4515e-04 - val_mean_absolute_percentage_error: 2.8116 - val_root_mean_squared_error: 0.0186
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 3.2018e-04 - mean_absolute_percentage_error: 19590.6465 - root_mean_squared_error: 0.0178 - val_loss: 3.2995e-04 - val_mean_absolute_percentage_error: 2.3655 - val_root_mean_squared_error: 0.0182
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.7077e-04 - mean_absolute_percentage_error: 16935.3945 - root_mean_squared_error: 0.0128 - val_loss: 2.9611e-04 - val_mean_absolute_percentage_error: 1.7699 - val_root_mean_squared_error: 0.0172
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 1.7302e-04 - mean_absolute_percentage_error: 23753.9141 - root_mean_squared_error: 0.0129 - val_loss: 2.8963e-04 - val_mean_absolute_percentage_error: 1.6758 - val_root_mean_squared_error: 0.0170
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 1.6492e-04 - mean_absolute_percentage_error: 14471.4521 - root_mean_squared_error: 0.0126 - val_loss: 3.3360e-04 - val_mean_absolute_percentage_error: 2.5453 - val_root_mean_squared_error: 0.0183
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 4.8312e-04 - mean_absolute_percentage_error: 12330.7393 - root_mean_squared_error: 0.0218 - val_loss: 7.4309e-04 - val_mean_absolute_percentage_error: 4.8008 - val_root_mean_squared_error: 0.0273
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 3.4285e-04 - mean_absolute_percentage_error: 26142.3750 - root_mean_squared_error: 0.0184 - val_loss: 3.8554e-04 - val_mean_absolute_percentage_error: 2.6916 - val_root_mean_squared_error: 0.0196
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step
#           0         1         2         3
# 0  9.444991  8.991616  6.737999  5.722768
# 11/11 [==============================] - 2s 163ms/step - loss: 3.2477e-04 - root_mean_squared_error: 0.0180 - mean_absolute_percentage_error: 45782.0977 - val_loss: 5.5485e-04 - val_root_mean_squared_error: 0.0236 - val_mean_absolute_percentage_error: 3.8501
# Epoch 22/50
# 11/11 [==============================] - 1s 135ms/step - loss: 4.2973e-04 - root_mean_squared_error: 0.0207 - mean_absolute_percentage_error: 24325.6738 - val_loss: 4.6673e-04 - val_root_mean_squared_error: 0.0216 - val_mean_absolute_percentage_error: 2.8881
# Epoch 23/50
# 11/11 [==============================] - 2s 138ms/step - loss: 5.4685e-04 - root_mean_squared_error: 0.0234 - mean_absolute_percentage_error: 100013.6172 - val_loss: 5.6858e-04 - val_root_mean_squared_error: 0.0238 - val_mean_absolute_percentage_error: 3.6687
# Epoch 24/50
# 11/11 [==============================] - 2s 141ms/step - loss: 4.1403e-04 - root_mean_squared_error: 0.0203 - mean_absolute_percentage_error: 53973.3789 - val_loss: 3.5775e-04 - val_root_mean_squared_error: 0.0189 - val_mean_absolute_percentage_error: 2.6380
# Epoch 25/50
# 11/11 [==============================] - 1s 138ms/step - loss: 3.0361e-04 - root_mean_squared_error: 0.0174 - mean_absolute_percentage_error: 14279.9727 - val_loss: 3.4060e-04 - val_root_mean_squared_error: 0.0185 - val_mean_absolute_percentage_error: 1.9893
# Epoch 26/50
# 11/11 [==============================] - 2s 140ms/step - loss: 2.9268e-04 - root_mean_squared_error: 0.0171 - mean_absolute_percentage_error: 106629.9531 - val_loss: 3.8161e-04 - val_root_mean_squared_error: 0.0195 - val_mean_absolute_percentage_error: 2.4099
# Epoch 27/50
# 11/11 [==============================] - 1s 130ms/step - loss: 3.6627e-04 - root_mean_squared_error: 0.0191 - mean_absolute_percentage_error: 70898.9141 - val_loss: 5.6394e-04 - val_root_mean_squared_error: 0.0237 - val_mean_absolute_percentage_error: 3.8419
# Epoch 28/50
# 11/11 [==============================] - 1s 127ms/step - loss: 4.7877e-04 - root_mean_squared_error: 0.0219 - mean_absolute_percentage_error: 117833.1641 - val_loss: 6.7993e-04 - val_root_mean_squared_error: 0.0261 - val_mean_absolute_percentage_error: 4.7476
# Epoch 29/50
# 11/11 [==============================] - 1s 128ms/step - loss: 3.6803e-04 - root_mean_squared_error: 0.0192 - mean_absolute_percentage_error: 10318.7266 - val_loss: 3.3188e-04 - val_root_mean_squared_error: 0.0182 - val_mean_absolute_percentage_error: 1.9705
# Epoch 30/50
# 11/11 [==============================] - 1s 134ms/step - loss: 3.9544e-04 - root_mean_squared_error: 0.0199 - mean_absolute_percentage_error: 52592.3516 - val_loss: 3.0750e-04 - val_root_mean_squared_error: 0.0175 - val_mean_absolute_percentage_error: 1.8994
# Epoch 31/50
# 11/11 [==============================] - 1s 134ms/step - loss: 3.1109e-04 - root_mean_squared_error: 0.0176 - mean_absolute_percentage_error: 22063.6758 - val_loss: 3.1687e-04 - val_root_mean_squared_error: 0.0178 - val_mean_absolute_percentage_error: 2.0743
# Epoch 32/50
# 11/11 [==============================] - 1s 133ms/step - loss: 3.2941e-04 - root_mean_squared_error: 0.0181 - mean_absolute_percentage_error: 109206.3828 - val_loss: 5.6672e-04 - val_root_mean_squared_error: 0.0238 - val_mean_absolute_percentage_error: 3.8238
# Epoch 33/50
# 11/11 [==============================] - 1s 124ms/step - loss: 3.1301e-04 - root_mean_squared_error: 0.0177 - mean_absolute_percentage_error: 76092.4375 - val_loss: 5.8132e-04 - val_root_mean_squared_error: 0.0241 - val_mean_absolute_percentage_error: 4.2186
# Epoch 34/50
# 11/11 [==============================] - 1s 129ms/step - loss: 3.3598e-04 - root_mean_squared_error: 0.0183 - mean_absolute_percentage_error: 46954.2070 - val_loss: 2.9249e-04 - val_root_mean_squared_error: 0.0171 - val_mean_absolute_percentage_error: 1.7709
# Epoch 35/50
# 11/11 [==============================] - 1s 132ms/step - loss: 2.3894e-04 - root_mean_squared_error: 0.0155 - mean_absolute_percentage_error: 42124.1523 - val_loss: 3.5387e-04 - val_root_mean_squared_error: 0.0188 - val_mean_absolute_percentage_error: 2.1430
# Epoch 36/50
# 11/11 [==============================] - 1s 126ms/step - loss: 2.1679e-04 - root_mean_squared_error: 0.0147 - mean_absolute_percentage_error: 48473.4961 - val_loss: 3.3578e-04 - val_root_mean_squared_error: 0.0183 - val_mean_absolute_percentage_error: 2.0418
# Epoch 37/50
# 11/11 [==============================] - 1s 126ms/step - loss: 2.4866e-04 - root_mean_squared_error: 0.0158 - mean_absolute_percentage_error: 65809.2422 - val_loss: 3.0370e-04 - val_root_mean_squared_error: 0.0174 - val_mean_absolute_percentage_error: 1.9205
# Epoch 38/50
# 11/11 [==============================] - 1s 131ms/step - loss: 1.9623e-04 - root_mean_squared_error: 0.0140 - mean_absolute_percentage_error: 73197.0156 - val_loss: 3.3629e-04 - val_root_mean_squared_error: 0.0183 - val_mean_absolute_percentage_error: 2.1348
# Epoch 39/50
# 11/11 [==============================] - 1s 131ms/step - loss: 2.7398e-04 - root_mean_squared_error: 0.0166 - mean_absolute_percentage_error: 61049.0938 - val_loss: 3.8691e-04 - val_root_mean_squared_error: 0.0197 - val_mean_absolute_percentage_error: 2.6999
# Epoch 40/50
# 11/11 [==============================] - 1s 137ms/step - loss: 5.4636e-04 - root_mean_squared_error: 0.0234 - mean_absolute_percentage_error: 36656.1289 - val_loss: 5.8127e-04 - val_root_mean_squared_error: 0.0241 - val_mean_absolute_percentage_error: 4.1067
# Epoch 41/50
# 11/11 [==============================] - 1s 126ms/step - loss: 2.6944e-04 - root_mean_squared_error: 0.0164 - mean_absolute_percentage_error: 30207.9023 - val_loss: 3.6792e-04 - val_root_mean_squared_error: 0.0192 - val_mean_absolute_percentage_error: 2.3866
# Epoch 42/50
# 11/11 [==============================] - 1s 131ms/step - loss: 2.1622e-04 - root_mean_squared_error: 0.0147 - mean_absolute_percentage_error: 68703.4609 - val_loss: 2.7817e-04 - val_root_mean_squared_error: 0.0167 - val_mean_absolute_percentage_error: 1.7048
# Epoch 43/50
# 11/11 [==============================] - 1s 128ms/step - loss: 2.8045e-04 - root_mean_squared_error: 0.0167 - mean_absolute_percentage_error: 27007.8867 - val_loss: 4.6147e-04 - val_root_mean_squared_error: 0.0215 - val_mean_absolute_percentage_error: 3.2129
# Epoch 44/50
# 11/11 [==============================] - 1s 126ms/step - loss: 2.7733e-04 - root_mean_squared_error: 0.0167 - mean_absolute_percentage_error: 50514.1055 - val_loss: 3.3749e-04 - val_root_mean_squared_error: 0.0184 - val_mean_absolute_percentage_error: 2.2414
# Epoch 45/50
# 11/11 [==============================] - 1s 126ms/step - loss: 2.5860e-04 - root_mean_squared_error: 0.0161 - mean_absolute_percentage_error: 57214.2461 - val_loss: 3.1651e-04 - val_root_mean_squared_error: 0.0178 - val_mean_absolute_percentage_error: 1.9794
# Epoch 46/50
# 11/11 [==============================] - 1s 125ms/step - loss: 3.8417e-04 - root_mean_squared_error: 0.0196 - mean_absolute_percentage_error: 58397.3750 - val_loss: 4.0717e-04 - val_root_mean_squared_error: 0.0202 - val_mean_absolute_percentage_error: 2.8853
# Epoch 47/50
# 11/11 [==============================] - 1s 125ms/step - loss: 2.9332e-04 - root_mean_squared_error: 0.0171 - mean_absolute_percentage_error: 26372.2148 - val_loss: 4.1808e-04 - val_root_mean_squared_error: 0.0204 - val_mean_absolute_percentage_error: 2.9851
# Epoch 48/50
# 11/11 [==============================] - 1s 122ms/step - loss: 2.5964e-04 - root_mean_squared_error: 0.0161 - mean_absolute_percentage_error: 29888.0820 - val_loss: 2.9770e-04 - val_root_mean_squared_error: 0.0173 - val_mean_absolute_percentage_error: 1.7987
# Epoch 49/50
# 11/11 [==============================] - 1s 125ms/step - loss: 3.4185e-04 - root_mean_squared_error: 0.0185 - mean_absolute_percentage_error: 58951.4297 - val_loss: 3.2870e-04 - val_root_mean_squared_error: 0.0181 - val_mean_absolute_percentage_error: 2.3026
# Epoch 50/50
# 11/11 [==============================] - 1s 121ms/step - loss: 2.4219e-04 - root_mean_squared_error: 0.0156 - mean_absolute_percentage_error: 275.6432 - val_loss: 2.7741e-04 - val_root_mean_squared_error: 0.0167 - val_mean_absolute_percentage_error: 1.6206
# 15/15 [==============================] - 1s 53ms/step
#            0          1         2          3
# 0  12.620843  12.301081  9.949759  10.121764
# 1   7.862595   7.538553  3.672355   3.003798
# 2   7.791223   7.685844  3.874424   3.577409
