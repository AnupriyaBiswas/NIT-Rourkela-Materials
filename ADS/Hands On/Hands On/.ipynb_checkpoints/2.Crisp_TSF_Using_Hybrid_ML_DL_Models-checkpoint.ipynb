# %%
# Import required packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
import os
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from sklearn.decomposition import PCA

# %%
from keras.models import Sequential
from keras.layers import Dense,Flatten,LSTM, GRU
from keras.callbacks import ModelCheckpoint,EarlyStopping
from keras.metrics import RootMeanSquaredError,mean_absolute_percentage_error
from keras.losses import MeanSquaredError
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Dropout
from keras.models import Model
from tensorflow.python.ops.numpy_ops import np_config
np_config.enable_numpy_behavior()

# %%
# split a univariate time series into patterns
def get_Patterns(TSeries, n_inputs,h):
    X,y,z = pd.DataFrame(np.zeros((len(TSeries)-n_inputs-h+1,n_inputs))), pd.DataFrame(), pd.DataFrame()
    for i in range(len(TSeries)):
        # find the end of this pattern
        end_ix = i + n_inputs + h - 1
        # check if we are beyond the time series
        if end_ix > len(TSeries)-1:
            break
        # gather input and output parts of the pattern
        for j in range(n_inputs):
            X.loc[i,j]=TSeries.iloc[i+j,0]
        i=i+n_inputs
        y=y.append(TSeries.iloc[end_ix], ignore_index = True)
    return np.array(X),np.array(y)

# %%
# originalData should be a Column Vectored DataFrame
def minmaxNorm(originalData, lenTrainValidation):
    max2norm=max(originalData.iloc[0:lenTrainValidation,0])
    min2norm=min(originalData.iloc[0:lenTrainValidation,0])
    lenOriginal=len(originalData)
    normalizedData=np.zeros(lenOriginal)   
    normalizedData = []
    for i in range (lenOriginal):
        normalizedData.append((originalData.iloc[i]-min2norm)/(max2norm-min2norm))    
    return pd.DataFrame(normalizedData)

# %%
# originalData and forecastedData should be Column Vectored DataFrames
def minmaxDeNorm( originalData, forecastedData, lenTrainValidation):
    max2norm=max(originalData.iloc[0:lenTrainValidation,0])
    min2norm=min(originalData.iloc[0:lenTrainValidation,0])
    lenOriginal=len(originalData)
    denormalizedData=[]    
    for i in range (lenOriginal):
        denormalizedData.append((forecastedData.iloc[i]*(max2norm-min2norm))+min2norm)  
    return pd.DataFrame(denormalizedData)

# %%
# Timeseries_Data and forecasted_value should be Column Vectored DataFrames
def findRMSE( Timeseries_Data, forecasted_value,lenTrainValidation):
    l=Timeseries_Data.shape[0]
    lenTest=l-lenTrainValidation
    trainRMSE=0;
    for i in range (lenTrainValidation):
        trainRMSE=trainRMSE+np.power((forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0]),2) 
    trainRMSE=np.sqrt(trainRMSE/lenTrainValidation)

    testRMSE=0;
    for i in range (lenTrainValidation,l,1):
        testRMSE=testRMSE+np.power((forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0]),2)
    testRMSE=np.sqrt(testRMSE/lenTest)
    return trainRMSE, testRMSE

# %%
# Timeseries_Data and forecasted_value should be Column Vectored DataFrames
def findMAE( Timeseries_Data, forecasted_value,lenTrainValidation):
    l=Timeseries_Data.shape[0]
    lenTest=l-lenTrainValidation
    trainMAE=0;
    for i in range (lenTrainValidation):
        trainMAE=trainMAE+np.abs(forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0]) 
    trainMAE=(trainMAE/(lenTrainValidation));

    testMAE=0;
    for i in range (lenTrainValidation,l,1):
        testMAE=testMAE+np.abs(forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0])
    testMAE=(testMAE/lenTest);
    return trainMAE, testMAE

# %%
def Find_Features_LSTM(x,y,lenValid,lenTest):
    NOP=len(y)
    n_features=1
    lenTrain=NOP-lenValid-lenTest
    LagLength=x.shape[1]
    xTrain=x[0:lenTrain,:]
    xValid=x[lenTrain:(lenTrain+lenValid),:]
    xTest=x[(lenTrain+lenValid):NOP,:]
    yTrain=y[0:lenTrain,0]
    yValid=y[lenTrain:(lenTrain+lenValid),0]
    yTest=y[(lenTrain+lenValid):NOP,0]
    model1 = Sequential()
    model1.add(LSTM(256, activation='tanh', input_shape=(LagLength,n_features),kernel_initializer="he_normal",name="layer1"))
    model1.add(Flatten())
    model1.add(Dense(16, activation='relu',kernel_initializer="he_normal"))
    model1.add(Dense(1,activation='linear'))
    checkpoint_filepath = './'
    cp1=ModelCheckpoint(checkpoint_filepath,save_best_only='True')
    model1.compile(loss=MeanSquaredError(),optimizer=Adam(learning_rate=0.01),metrics=[RootMeanSquaredError()])
    # fit
    model1.fit(xTrain, yTrain,validation_data=(xValid,yValid), epochs=100, verbose=1,batch_size=16)
    yhatNorm=model1.predict(x).flatten().reshape(x.shape[0],1)
    feature_extractor = Model(inputs=model1.inputs, outputs=model1.get_layer(name="layer1").output)
    features = pd.DataFrame(feature_extractor(x))
    return features

# %%
def Find_Fitness(x,y,lenValid,lenTest,model):
    NOP=y.shape[0]
    lenTrain=NOP-lenValid-lenTest
    xTrain=x[0:(lenTrain+lenValid),:]
    xValid=x[lenTrain:(lenTrain+lenValid),:]
    xTest=x[(lenTrain+lenValid):NOP,:]
    yTrain=y[0:(lenTrain+lenValid),0]
    yValid=y[lenTrain:(lenTrain+lenValid),0]
    yTest=y[(lenTrain+lenValid):NOP,0]
    model.fit(xTrain, yTrain)
    yhatNorm=model.predict(x).flatten().reshape(x.shape[0],1)
    return pd.DataFrame(yhatNorm)

# %%
#Read the Time Series Dataset
Timeseries_Data=pd.read_csv('AQI.csv',header=None)
LagLength=24
h=1
NumberOfRepeatitions=2
lt=Timeseries_Data.shape[0]
lenTrain=int(round(lt*0.6))
lenValidation=int(round(lt*0.2))
lenTest=int(lt-lenTrain-lenValidation)
# NORMALIZE THE DATA
normalizedData=minmaxNorm(Timeseries_Data,lenTrain+lenValidation);
# Transform the Time Series into Patterns Using Sliding Window
X, y = get_Patterns(normalizedData, LagLength, h)
LSTMFeatures=Find_Features_LSTM(X,y,lenValidation,lenTest)
#X=np.hstack((LSTMFeatures,GRUFeatures))
#X = SelectKBest(score_func=f_regression, k=24).fit_transform(X, y)
X=np.array(LSTMFeatures)
#pca = PCA(n_components=24)
#X = pca.fit_transform(X)
MeanAccuracyT=pd.DataFrame()
StdAccuracyT=pd.DataFrame()
model=RandomForestRegressor()
name='9.RandomForestRegressor'
file1='./'+str(name)+"_Accuracy.xlsx"
file2='./'+str(name)+"_Forecasts.xlsx"
Forecasts=pd.DataFrame()
Accuracy=pd.DataFrame()
ynorm1=Find_Fitness(X,y,lenValidation,lenTest,model)
ynorm=pd.DataFrame(normalizedData.iloc[0:LagLength,0])
ynorm=ynorm.append(ynorm1,ignore_index = True)
yhat=minmaxDeNorm(Timeseries_Data, ynorm, lenTrain+lenValidation)
Accuracy.loc[0,0],Accuracy.loc[0,1]=findRMSE( Timeseries_Data,yhat,lenTrain+lenValidation)
Accuracy.loc[0,2],Accuracy.loc[0,3]=findMAE( Timeseries_Data,yhat,lenTrain+lenValidation)
Forecasts=Forecasts.append(yhat.T,ignore_index = True)
Accuracy.to_excel(file1,sheet_name='Accuracy',index=False)
Forecasts.T.to_excel(file2,sheet_name='Forecasts',index=False)
Accuracy
# Out:
# Epoch 1/100
# 18/18 [==============================] - 39s 786ms/step - loss: 1.1161 - root_mean_squared_error: 1.0565 - val_loss: 0.2051 - val_root_mean_squared_error: 0.4529
# Epoch 2/100
# 18/18 [==============================] - 4s 202ms/step - loss: 0.1829 - root_mean_squared_error: 0.4277 - val_loss: 0.1387 - val_root_mean_squared_error: 0.3724
# Epoch 3/100
# 18/18 [==============================] - 3s 189ms/step - loss: 0.1206 - root_mean_squared_error: 0.3473 - val_loss: 0.0809 - val_root_mean_squared_error: 0.2844
# Epoch 4/100
# 18/18 [==============================] - 4s 203ms/step - loss: 0.0740 - root_mean_squared_error: 0.2721 - val_loss: 0.0418 - val_root_mean_squared_error: 0.2044
# Epoch 5/100
# 18/18 [==============================] - 3s 188ms/step - loss: 0.0450 - root_mean_squared_error: 0.2122 - val_loss: 0.0197 - val_root_mean_squared_error: 0.1405
# Epoch 6/100
# 18/18 [==============================] - 4s 206ms/step - loss: 0.0304 - root_mean_squared_error: 0.1743 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0954
# Epoch 7/100
# 18/18 [==============================] - 3s 192ms/step - loss: 0.0237 - root_mean_squared_error: 0.1538 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0670
# Epoch 8/100
# 18/18 [==============================] - 3s 187ms/step - loss: 0.0210 - root_mean_squared_error: 0.1450 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0486
# Epoch 9/100
# 18/18 [==============================] - 4s 216ms/step - loss: 0.0201 - root_mean_squared_error: 0.1416 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0391
# Epoch 10/100
# 18/18 [==============================] - 4s 196ms/step - loss: 0.0198 - root_mean_squared_error: 0.1406 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0342
# Epoch 11/100
# 18/18 [==============================] - 3s 167ms/step - loss: 0.0196 - root_mean_squared_error: 0.1401 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0320
# Epoch 12/100
# 18/18 [==============================] - 4s 211ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 9.3728e-04 - val_root_mean_squared_error: 0.0306
# Epoch 13/100
# 18/18 [==============================] - 4s 228ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0317
# Epoch 14/100
# 18/18 [==============================] - 3s 181ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 9.6884e-04 - val_root_mean_squared_error: 0.0311
# Epoch 15/100
# 18/18 [==============================] - 3s 184ms/step - loss: 0.0196 - root_mean_squared_error: 0.1401 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0320
# Epoch 16/100
# 18/18 [==============================] - 3s 183ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0323
# Epoch 17/100
# 18/18 [==============================] - 3s 178ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 9.8823e-04 - val_root_mean_squared_error: 0.0314
# Epoch 18/100
# 18/18 [==============================] - 4s 201ms/step - loss: 0.0196 - root_mean_squared_error: 0.1401 - val_loss: 9.4946e-04 - val_root_mean_squared_error: 0.0308
# Epoch 19/100
# 18/18 [==============================] - 4s 201ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 9.6831e-04 - val_root_mean_squared_error: 0.0311
# Epoch 20/100
# 18/18 [==============================] - 4s 198ms/step - loss: 0.0196 - root_mean_squared_error: 0.1399 - val_loss: 9.3792e-04 - val_root_mean_squared_error: 0.0306
# Epoch 21/100
# 18/18 [==============================] - 3s 191ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 9.4715e-04 - val_root_mean_squared_error: 0.0308
# Epoch 22/100
# 18/18 [==============================] - 4s 208ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0316
# Epoch 23/100
# 18/18 [==============================] - 4s 209ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 9.0608e-04 - val_root_mean_squared_error: 0.0301
# Epoch 24/100
# 18/18 [==============================] - 4s 206ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 9.1107e-04 - val_root_mean_squared_error: 0.0302
# Epoch 25/100
# 18/18 [==============================] - 3s 188ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0319
# Epoch 26/100
# 18/18 [==============================] - 4s 220ms/step - loss: 0.0196 - root_mean_squared_error: 0.1399 - val_loss: 9.5177e-04 - val_root_mean_squared_error: 0.0309
# Epoch 27/100
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 9.1334e-04 - val_root_mean_squared_error: 0.0302
# Epoch 28/100
# 18/18 [==============================] - 4s 211ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 9.7907e-04 - val_root_mean_squared_error: 0.0313
# Epoch 29/100
# 18/18 [==============================] - 4s 235ms/step - loss: 0.0197 - root_mean_squared_error: 0.1403 - val_loss: 8.6565e-04 - val_root_mean_squared_error: 0.0294
# Epoch 30/100
# 18/18 [==============================] - 4s 213ms/step - loss: 0.0196 - root_mean_squared_error: 0.1399 - val_loss: 9.9316e-04 - val_root_mean_squared_error: 0.0315
# Epoch 31/100
# 18/18 [==============================] - 5s 286ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0317
# Epoch 32/100
# 18/18 [==============================] - 5s 261ms/step - loss: 0.0197 - root_mean_squared_error: 0.1402 - val_loss: 9.0368e-04 - val_root_mean_squared_error: 0.0301
# Epoch 33/100
# 18/18 [==============================] - 5s 265ms/step - loss: 0.0196 - root_mean_squared_error: 0.1399 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0323
# Epoch 34/100
# 18/18 [==============================] - 5s 272ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 9.6709e-04 - val_root_mean_squared_error: 0.0311
# Epoch 35/100
# 18/18 [==============================] - 8s 433ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 9.4251e-04 - val_root_mean_squared_error: 0.0307
# Epoch 36/100
# 18/18 [==============================] - 6s 339ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0318
# Epoch 37/100
# 18/18 [==============================] - 5s 300ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 9.3648e-04 - val_root_mean_squared_error: 0.0306
# Epoch 38/100
# 18/18 [==============================] - 5s 254ms/step - loss: 0.0196 - root_mean_squared_error: 0.1401 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0318
# Epoch 39/100
# 18/18 [==============================] - 4s 224ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 9.2915e-04 - val_root_mean_squared_error: 0.0305
# Epoch 40/100
# 18/18 [==============================] - 4s 222ms/step - loss: 0.0197 - root_mean_squared_error: 0.1403 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0331
# Epoch 41/100
# 18/18 [==============================] - 4s 246ms/step - loss: 0.0196 - root_mean_squared_error: 0.1399 - val_loss: 9.3643e-04 - val_root_mean_squared_error: 0.0306
# Epoch 42/100
# 18/18 [==============================] - 6s 360ms/step - loss: 0.0196 - root_mean_squared_error: 0.1401 - val_loss: 9.8126e-04 - val_root_mean_squared_error: 0.0313
# Epoch 43/100
# 18/18 [==============================] - 6s 332ms/step - loss: 0.0196 - root_mean_squared_error: 0.1401 - val_loss: 9.5549e-04 - val_root_mean_squared_error: 0.0309
# Epoch 44/100
# 18/18 [==============================] - 5s 286ms/step - loss: 0.0196 - root_mean_squared_error: 0.1401 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0318
# Epoch 45/100
# 18/18 [==============================] - 4s 248ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0320
# Epoch 46/100
# 18/18 [==============================] - 5s 275ms/step - loss: 0.0196 - root_mean_squared_error: 0.1401 - val_loss: 9.1904e-04 - val_root_mean_squared_error: 0.0303
# Epoch 47/100
# 18/18 [==============================] - 4s 239ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 9.2542e-04 - val_root_mean_squared_error: 0.0304
# Epoch 48/100
# 18/18 [==============================] - 4s 219ms/step - loss: 0.0197 - root_mean_squared_error: 0.1403 - val_loss: 8.7855e-04 - val_root_mean_squared_error: 0.0296
# Epoch 49/100
# 18/18 [==============================] - 4s 199ms/step - loss: 0.0196 - root_mean_squared_error: 0.1399 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0325
# Epoch 50/100
# 18/18 [==============================] - 4s 250ms/step - loss: 0.0196 - root_mean_squared_error: 0.1401 - val_loss: 9.7541e-04 - val_root_mean_squared_error: 0.0312
# Epoch 51/100
# 18/18 [==============================] - 3s 196ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 9.3366e-04 - val_root_mean_squared_error: 0.0306
# Epoch 83/100
# 18/18 [==============================] - 3s 196ms/step - loss: 0.0197 - root_mean_squared_error: 0.1404 - val_loss: 9.7235e-04 - val_root_mean_squared_error: 0.0312
# Epoch 84/100
# 18/18 [==============================] - 4s 195ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0327
# Epoch 85/100
# 18/18 [==============================] - 3s 193ms/step - loss: 0.0196 - root_mean_squared_error: 0.1402 - val_loss: 9.0643e-04 - val_root_mean_squared_error: 0.0301
# Epoch 86/100
# 18/18 [==============================] - 2s 129ms/step - loss: 0.0196 - root_mean_squared_error: 0.1399 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0317
# Epoch 87/100
# 18/18 [==============================] - 2s 113ms/step - loss: 0.0197 - root_mean_squared_error: 0.1403 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0341
# Epoch 88/100
# 18/18 [==============================] - 2s 123ms/step - loss: 0.0196 - root_mean_squared_error: 0.1401 - val_loss: 8.7185e-04 - val_root_mean_squared_error: 0.0295
# Epoch 89/100
# 18/18 [==============================] - 2s 125ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0321
# Epoch 90/100
# 18/18 [==============================] - 3s 143ms/step - loss: 0.0197 - root_mean_squared_error: 0.1402 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0334
# Epoch 91/100
# 18/18 [==============================] - 2s 122ms/step - loss: 0.0197 - root_mean_squared_error: 0.1402 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0321
# Epoch 92/100
# 18/18 [==============================] - 2s 112ms/step - loss: 0.0198 - root_mean_squared_error: 0.1406 - val_loss: 7.9577e-04 - val_root_mean_squared_error: 0.0282
# Epoch 93/100
# 18/18 [==============================] - 2s 136ms/step - loss: 0.0197 - root_mean_squared_error: 0.1403 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0346
# Epoch 94/100
# 18/18 [==============================] - 2s 111ms/step - loss: 0.0196 - root_mean_squared_error: 0.1401 - val_loss: 9.3387e-04 - val_root_mean_squared_error: 0.0306
# Epoch 95/100
# 18/18 [==============================] - 2s 128ms/step - loss: 0.0196 - root_mean_squared_error: 0.1402 - val_loss: 8.5726e-04 - val_root_mean_squared_error: 0.0293
# Epoch 96/100
# 18/18 [==============================] - 2s 119ms/step - loss: 0.0196 - root_mean_squared_error: 0.1399 - val_loss: 9.9315e-04 - val_root_mean_squared_error: 0.0315
# Epoch 97/100
# 18/18 [==============================] - 2s 107ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 9.7898e-04 - val_root_mean_squared_error: 0.0313
# Epoch 98/100
# 18/18 [==============================] - 2s 111ms/step - loss: 0.0196 - root_mean_squared_error: 0.1400 - val_loss: 8.7666e-04 - val_root_mean_squared_error: 0.0296
# Epoch 99/100
# 18/18 [==============================] - 2s 109ms/step - loss: 0.0197 - root_mean_squared_error: 0.1402 - val_loss: 9.3413e-04 - val_root_mean_squared_error: 0.0306
# Epoch 100/100
# 18/18 [==============================] - 2s 117ms/step - loss: 0.0197 - root_mean_squared_error: 0.1403 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0329
# 15/15 [==============================] - 3s 74ms/step
#           0         1         2       3
# 0  4.095979  6.806957  1.716425  3.4906
