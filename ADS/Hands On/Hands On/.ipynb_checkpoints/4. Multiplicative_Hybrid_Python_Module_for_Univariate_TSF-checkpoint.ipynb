# %%
# Import required packages
import numpy as np
import pandas as pd
import os
import warnings
warnings.filterwarnings("ignore")

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten,LSTM
from keras.callbacks import ModelCheckpoint,EarlyStopping
from keras.metrics import RootMeanSquaredError,mean_absolute_percentage_error
from keras.losses import MeanSquaredError
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model

# %%
# split a univariate time series into patterns
def get_Patterns(TSeries, n_inputs,h):
    X,y,z = pd.DataFrame(np.zeros((len(TSeries)-n_inputs-h+1,n_inputs))), pd.DataFrame(), pd.DataFrame()
    for i in range(len(TSeries)):
        # find the end of this pattern
        end_ix = i + n_inputs + h - 1
        # check if we are beyond the time series
        if end_ix > len(TSeries)-1:
            break
        # gather input and output parts of the pattern
        for j in range(n_inputs):
            X.loc[i,j]=TSeries.iloc[i+j,0]
        i=i+n_inputs
        #y=y.append(TSeries.iloc[end_ix], ignore_index = True)
        y=pd.concat([y, TSeries.iloc[end_ix]], ignore_index=True)
    return pd.DataFrame(X),pd.DataFrame(y)

# %%
# originalData should be a Column Vectored DataFrame
def minmaxNorm(originalData, lenTrainValidation):
    # Maximum Value
    max2norm=max(originalData.iloc[0:lenTrainValidation,0])
    # Minimum Value
    min2norm=min(originalData.iloc[0:lenTrainValidation,0])
    lenOriginal=len(originalData)
    normalizedData=np.zeros(lenOriginal)   
    normalizedData = []
    #Normalize using Min-Max Normalization
    for i in range (lenOriginal):
        normalizedData.append((originalData.iloc[i]-min2norm)/(max2norm-min2norm))    
    return pd.DataFrame(normalizedData)

# %%
# originalData and forecastedData should be Column Vectored DataFrames
def minmaxDeNorm( originalData, forecastedData, lenTrainValidation):
    # Maximum Value
    max2norm=max(originalData.iloc[0:lenTrainValidation,0])
    # Minimum Value
    min2norm=min(originalData.iloc[0:lenTrainValidation,0])
    lenOriginal=len(originalData)
    denormalizedData=[]   
    #De-Normalize using Min-Max Normalization
    for i in range (lenOriginal):
        denormalizedData.append((forecastedData.iloc[i]*(max2norm-min2norm))+min2norm)  
    return pd.DataFrame(denormalizedData)

# %%
# Timeseries_Data and forecasted_value should be Column Vectored DataFrames
def findRMSE( Timeseries_Data, forecasted_value,lenTrainValidation):
    l=Timeseries_Data.shape[0]
    lenTest=l-lenTrainValidation
    trainRMSE=0;
    for i in range (lenTrainValidation):
        trainRMSE=trainRMSE+np.power((forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0]),2) 
    trainRMSE=np.sqrt(trainRMSE/lenTrainValidation)

    testRMSE=0;
    for i in range (lenTrainValidation,l,1):
        testRMSE=testRMSE+np.power((forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0]),2)
    testRMSE=np.sqrt(testRMSE/lenTest)
    return trainRMSE, testRMSE

# %%
# Timeseries_Data and forecasted_value should be Column Vectored DataFrames
def findMAE( Timeseries_Data, forecasted_value,lenTrainValidation):
    l=Timeseries_Data.shape[0]
    lenTest=l-lenTrainValidation
    trainMAE=0;
    for i in range (lenTrainValidation):
        trainMAE=trainMAE+np.abs(forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0]) 
    trainMAE=(trainMAE/(lenTrainValidation));

    testMAE=0;
    for i in range (lenTrainValidation,l,1):
        testMAE=testMAE+np.abs(forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0])
    testMAE=(testMAE/lenTest);
    return trainMAE, testMAE

# %%
def Find_Fitness_LSTM(x,y,lenValid,lenTest):
    NOP=len(y)
    n_features=1
    lenTrain=NOP-lenValid-lenTest
    xTrain=x.iloc[0:lenTrain,:]
    xValid=x.iloc[lenTrain:(lenTrain+lenValid),:]
    xTest=x.iloc[(lenTrain+lenValid):NOP,:]
    yTrain=y.iloc[0:lenTrain,0]
    yValid=y.iloc[lenTrain:(lenTrain+lenValid),0]
    yTest=y.iloc[(lenTrain+lenValid):NOP,0]
    model1 = Sequential()
    model1.add(LSTM(256, activation='relu', input_shape=(LagLength,n_features)))
    model1.add(Flatten())
    model1.add(Dense(128, activation='relu'))
    model1.add(Dense(64, activation='relu'))
    model1.add(Dense(32, activation='relu'))
    model1.add(Dense(1,activation='linear'))
    checkpoint_filepath = '/cp.keras'
    cp1=ModelCheckpoint(checkpoint_filepath,save_best_only='True')
    model1.compile(loss=MeanSquaredError(),optimizer=Adam(learning_rate=0.01),metrics=[RootMeanSquaredError(),mean_absolute_percentage_error])
    # fit
    model1.fit(xTrain, yTrain,validation_data=(xValid,yValid), epochs=50, verbose=1)
    yhatNorm=model1.predict(x).flatten().reshape(x.shape[0],1)
    return pd.DataFrame(yhatNorm)

# %%
#Read the Time Series Dataset
Timeseries_Data=pd.read_csv('AQI.csv',header=None)
linear_Data=pd.read_excel('linear.xlsx',header=None)
Residual_Data=Timeseries_Data
LagLength=24
h=1
lt=Timeseries_Data.shape[0]
lenTrain=int(round(lt*0.7))
lenValidation=int(round(lt*0.15))
lenTest=int(lt-lenTrain-lenValidation)
#Compute the Residual Series
for i in range(lt):
    Residual_Data.iloc[i]=Timeseries_Data.iloc[i]/linear_Data.iloc[i]
# NORMALIZE THE DATA
normalizedData=minmaxNorm(Residual_Data,lenTrain+lenValidation);
# Transform the Time Series into Patterns Using Sliding Window
X, y = get_Patterns(normalizedData, LagLength, h)
file1="Accuracy.xlsx"
file2="Forecasts.xlsx"
Forecasts=pd.DataFrame()
Accuracy=pd.DataFrame()
ynorm1=Find_Fitness_LSTM(X,y,lenValidation,lenTest)
ynorm=pd.DataFrame(normalizedData.iloc[0:(LagLength+h-1),0])
ynorm=pd.concat([ynorm, ynorm1], ignore_index=True)
yhat1=minmaxDeNorm(Residual_Data, ynorm, lenTrain+lenValidation)
yhat=yhat1
for i in range(lt):
    yhat.iloc[i]=yhat1.iloc[i]*linear_Data.iloc[i]
Accuracy.loc[0,0],Accuracy.loc[0,1]=findRMSE( Timeseries_Data,yhat,lenTrain+lenValidation)
Accuracy.loc[0,2],Accuracy.loc[0,3]=findMAE( Timeseries_Data,yhat,lenTrain+lenValidation)
Accuracy.to_excel(file1,sheet_name='Accuracy',index=False)
yhat.to_excel(file2,sheet_name='Forecasts',index=False)
print(Accuracy)
# Out:
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 8s 139ms/step - loss: 0.1074 - mean_absolute_percentage_error: 354888.3125 - root_mean_squared_error: 0.3201 - val_loss: 0.0100 - val_mean_absolute_percentage_error: 16.0086 - val_root_mean_squared_error: 0.0998
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - loss: 0.0086 - mean_absolute_percentage_error: 1632397.1250 - root_mean_squared_error: 0.0924 - val_loss: 0.0022 - val_mean_absolute_percentage_error: 7.3887 - val_root_mean_squared_error: 0.0467
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0068 - mean_absolute_percentage_error: 917081.8125 - root_mean_squared_error: 0.0826 - val_loss: 0.0027 - val_mean_absolute_percentage_error: 8.7345 - val_root_mean_squared_error: 0.0523
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0064 - mean_absolute_percentage_error: 778187.6250 - root_mean_squared_error: 0.0799 - val_loss: 0.0027 - val_mean_absolute_percentage_error: 8.7553 - val_root_mean_squared_error: 0.0524
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0050 - mean_absolute_percentage_error: 835126.5625 - root_mean_squared_error: 0.0703 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 6.7642 - val_root_mean_squared_error: 0.0429
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0060 - mean_absolute_percentage_error: 829682.7500 - root_mean_squared_error: 0.0765 - val_loss: 0.0017 - val_mean_absolute_percentage_error: 6.5792 - val_root_mean_squared_error: 0.0408
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0039 - mean_absolute_percentage_error: 1398167.6250 - root_mean_squared_error: 0.0619 - val_loss: 0.0012 - val_mean_absolute_percentage_error: 4.9678 - val_root_mean_squared_error: 0.0348
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0031 - mean_absolute_percentage_error: 349724.5938 - root_mean_squared_error: 0.0557 - val_loss: 8.7660e-04 - val_mean_absolute_percentage_error: 4.2739 - val_root_mean_squared_error: 0.0296
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0038 - mean_absolute_percentage_error: 591568.1250 - root_mean_squared_error: 0.0613 - val_loss: 9.8984e-04 - val_mean_absolute_percentage_error: 4.8780 - val_root_mean_squared_error: 0.0315
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0030 - mean_absolute_percentage_error: 330120.7188 - root_mean_squared_error: 0.0538 - val_loss: 7.9311e-04 - val_mean_absolute_percentage_error: 4.0015 - val_root_mean_squared_error: 0.0282
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0020 - mean_absolute_percentage_error: 746088.5625 - root_mean_squared_error: 0.0440 - val_loss: 7.4331e-04 - val_mean_absolute_percentage_error: 3.2727 - val_root_mean_squared_error: 0.0273
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0017 - mean_absolute_percentage_error: 1684416.6250 - root_mean_squared_error: 0.0413 - val_loss: 0.0014 - val_mean_absolute_percentage_error: 5.3185 - val_root_mean_squared_error: 0.0372
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0035 - mean_absolute_percentage_error: 115195.8125 - root_mean_squared_error: 0.0588 - val_loss: 0.0045 - val_mean_absolute_percentage_error: 11.3611 - val_root_mean_squared_error: 0.0671
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0035 - mean_absolute_percentage_error: 997204.6875 - root_mean_squared_error: 0.0588 - val_loss: 0.0016 - val_mean_absolute_percentage_error: 5.7984 - val_root_mean_squared_error: 0.0396
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0032 - mean_absolute_percentage_error: 479927.2500 - root_mean_squared_error: 0.0564 - val_loss: 0.0024 - val_mean_absolute_percentage_error: 8.5553 - val_root_mean_squared_error: 0.0489
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0027 - mean_absolute_percentage_error: 540484.8750 - root_mean_squared_error: 0.0519 - val_loss: 9.1378e-04 - val_mean_absolute_percentage_error: 3.9602 - val_root_mean_squared_error: 0.0302
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0021 - mean_absolute_percentage_error: 1567113.6250 - root_mean_squared_error: 0.0459 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 6.1380 - val_root_mean_squared_error: 0.0419
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0034 - mean_absolute_percentage_error: 760423.3125 - root_mean_squared_error: 0.0564 - val_loss: 8.0399e-04 - val_mean_absolute_percentage_error: 3.4827 - val_root_mean_squared_error: 0.0284
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0012 - mean_absolute_percentage_error: 276812.0625 - root_mean_squared_error: 0.0348 - val_loss: 0.0011 - val_mean_absolute_percentage_error: 4.6528 - val_root_mean_squared_error: 0.0335
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0024 - mean_absolute_percentage_error: 195861.3906 - root_mean_squared_error: 0.0477 - val_loss: 7.9302e-04 - val_mean_absolute_percentage_error: 3.4726 - val_root_mean_squared_error: 0.0282
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0023 - mean_absolute_percentage_error: 417940.1250 - root_mean_squared_error: 0.0470 - val_loss: 7.8308e-04 - val_mean_absolute_percentage_error: 3.5725 - val_root_mean_squared_error: 0.0280
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0021 - mean_absolute_percentage_error: 455069.8125 - root_mean_squared_error: 0.0450 - val_loss: 0.0016 - val_mean_absolute_percentage_error: 6.3539 - val_root_mean_squared_error: 0.0402
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0032 - mean_absolute_percentage_error: 86924.0156 - root_mean_squared_error: 0.0545 - val_loss: 0.0011 - val_mean_absolute_percentage_error: 4.5694 - val_root_mean_squared_error: 0.0328
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0013 - mean_absolute_percentage_error: 26498.7539 - root_mean_squared_error: 0.0357 - val_loss: 0.0012 - val_mean_absolute_percentage_error: 4.9064 - val_root_mean_squared_error: 0.0348
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0013 - mean_absolute_percentage_error: 54514.1133 - root_mean_squared_error: 0.0353 - val_loss: 0.0020 - val_mean_absolute_percentage_error: 6.9681 - val_root_mean_squared_error: 0.0446
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0018 - mean_absolute_percentage_error: 157562.3125 - root_mean_squared_error: 0.0427 - val_loss: 0.0013 - val_mean_absolute_percentage_error: 6.1483 - val_root_mean_squared_error: 0.0364
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0015 - mean_absolute_percentage_error: 35394.9258 - root_mean_squared_error: 0.0379 - val_loss: 7.5919e-04 - val_mean_absolute_percentage_error: 3.3059 - val_root_mean_squared_error: 0.0276
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0011 - mean_absolute_percentage_error: 242892.6094 - root_mean_squared_error: 0.0320 - val_loss: 6.4319e-04 - val_mean_absolute_percentage_error: 2.9577 - val_root_mean_squared_error: 0.0254
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 8.4574e-04 - mean_absolute_percentage_error: 107204.5156 - root_mean_squared_error: 0.0282 - val_loss: 6.2249e-04 - val_mean_absolute_percentage_error: 3.0629 - val_root_mean_squared_error: 0.0249
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0015 - mean_absolute_percentage_error: 54420.8242 - root_mean_squared_error: 0.0375 - val_loss: 0.0011 - val_mean_absolute_percentage_error: 5.3799 - val_root_mean_squared_error: 0.0330
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0011 - mean_absolute_percentage_error: 6829.7695 - root_mean_squared_error: 0.0334 - val_loss: 6.5442e-04 - val_mean_absolute_percentage_error: 3.4784 - val_root_mean_squared_error: 0.0256
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 9.6880e-04 - mean_absolute_percentage_error: 24087.6152 - root_mean_squared_error: 0.0296 - val_loss: 6.9458e-04 - val_mean_absolute_percentage_error: 3.8075 - val_root_mean_squared_error: 0.0264
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0013 - mean_absolute_percentage_error: 76474.7578 - root_mean_squared_error: 0.0360 - val_loss: 8.0213e-04 - val_mean_absolute_percentage_error: 3.3387 - val_root_mean_squared_error: 0.0283
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0011 - mean_absolute_percentage_error: 17384.9551 - root_mean_squared_error: 0.0315 - val_loss: 6.8067e-04 - val_mean_absolute_percentage_error: 2.9429 - val_root_mean_squared_error: 0.0261
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 9.8651e-04 - mean_absolute_percentage_error: 11411.3516 - root_mean_squared_error: 0.0304 - val_loss: 6.2541e-04 - val_mean_absolute_percentage_error: 2.9125 - val_root_mean_squared_error: 0.0250
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0013 - mean_absolute_percentage_error: 34079.3203 - root_mean_squared_error: 0.0345 - val_loss: 6.1393e-04 - val_mean_absolute_percentage_error: 2.8555 - val_root_mean_squared_error: 0.0248
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0016 - mean_absolute_percentage_error: 31731.2715 - root_mean_squared_error: 0.0392 - val_loss: 8.6689e-04 - val_mean_absolute_percentage_error: 3.8486 - val_root_mean_squared_error: 0.0294
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0010 - mean_absolute_percentage_error: 14188.1924 - root_mean_squared_error: 0.0319 - val_loss: 6.5839e-04 - val_mean_absolute_percentage_error: 3.2157 - val_root_mean_squared_error: 0.0257
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 8.2415e-04 - mean_absolute_percentage_error: 64004.4219 - root_mean_squared_error: 0.0280 - val_loss: 0.0015 - val_mean_absolute_percentage_error: 6.5244 - val_root_mean_squared_error: 0.0383
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0025 - mean_absolute_percentage_error: 65715.8047 - root_mean_squared_error: 0.0497 - val_loss: 0.0011 - val_mean_absolute_percentage_error: 5.3930 - val_root_mean_squared_error: 0.0331
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0017 - mean_absolute_percentage_error: 224564.1406 - root_mean_squared_error: 0.0402 - val_loss: 8.3417e-04 - val_mean_absolute_percentage_error: 4.4839 - val_root_mean_squared_error: 0.0289
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0014 - mean_absolute_percentage_error: 33664.7109 - root_mean_squared_error: 0.0372 - val_loss: 6.0192e-04 - val_mean_absolute_percentage_error: 2.9193 - val_root_mean_squared_error: 0.0245
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0011 - mean_absolute_percentage_error: 22774.0840 - root_mean_squared_error: 0.0328 - val_loss: 5.6723e-04 - val_mean_absolute_percentage_error: 2.4812 - val_root_mean_squared_error: 0.0238
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0013 - mean_absolute_percentage_error: 26731.3828 - root_mean_squared_error: 0.0352 - val_loss: 7.1013e-04 - val_mean_absolute_percentage_error: 3.0970 - val_root_mean_squared_error: 0.0266
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0020 - mean_absolute_percentage_error: 71331.2969 - root_mean_squared_error: 0.0433 - val_loss: 6.1652e-04 - val_mean_absolute_percentage_error: 3.2302 - val_root_mean_squared_error: 0.0248
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 7.0323e-04 - mean_absolute_percentage_error: 27759.0371 - root_mean_squared_error: 0.0260 - val_loss: 6.5040e-04 - val_mean_absolute_percentage_error: 3.4199 - val_root_mean_squared_error: 0.0255
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0013 - mean_absolute_percentage_error: 76056.7031 - root_mean_squared_error: 0.0360 - val_loss: 7.2897e-04 - val_mean_absolute_percentage_error: 3.9352 - val_root_mean_squared_error: 0.0270
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 9.2126e-04 - mean_absolute_percentage_error: 10056.8633 - root_mean_squared_error: 0.0294 - val_loss: 9.3080e-04 - val_mean_absolute_percentage_error: 4.1487 - val_root_mean_squared_error: 0.0305
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0011 - mean_absolute_percentage_error: 70845.4688 - root_mean_squared_error: 0.0317 - val_loss: 0.0011 - val_mean_absolute_percentage_error: 4.7230 - val_root_mean_squared_error: 0.0329
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0010 - mean_absolute_percentage_error: 118665.0312 - root_mean_squared_error: 0.0314 - val_loss: 7.8620e-04 - val_mean_absolute_percentage_error: 3.3419 - val_root_mean_squared_error: 0.0280
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step
#             0           1          2           3
# 0  357.939222  346.094201  350.74407  345.665609
