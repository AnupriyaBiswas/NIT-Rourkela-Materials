# %%
# Import required packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
import os
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
from sklearn.decomposition import PCA

# %%
from keras.models import Sequential
from keras.layers import Dense,Flatten,LSTM
from keras.callbacks import ModelCheckpoint,EarlyStopping
from keras.metrics import RootMeanSquaredError,mean_absolute_percentage_error
from keras.losses import MeanSquaredError
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Dropout
from keras.models import Model
from tensorflow.python.ops.numpy_ops import np_config
np_config.enable_numpy_behavior()

# %%
# split a univariate time series into patterns
def get_Patterns(TSeries, n_inputs,h):
    X,y,z = pd.DataFrame(np.zeros((len(TSeries)-n_inputs-h+1,n_inputs))), pd.DataFrame(), pd.DataFrame()
    for i in range(len(TSeries)):
        # find the end of this pattern
        end_ix = i + n_inputs + h - 1
        # check if we are beyond the time series
        if end_ix > len(TSeries)-1:
            break
        # gather input and output parts of the pattern
        for j in range(n_inputs):
            X.loc[i,j]=TSeries.iloc[i+j,0]
        i=i+n_inputs
        y=y.append(TSeries.iloc[end_ix], ignore_index = True)
    return np.array(X),np.array(y)

# %%
# originalData should be a Column Vectored DataFrame
def minmaxNorm(originalData, lenTrainValidation):
    max2norm=max(originalData.iloc[0:lenTrainValidation,0])
    min2norm=min(originalData.iloc[0:lenTrainValidation,0])
    lenOriginal=len(originalData)
    normalizedData=np.zeros(lenOriginal)   
    normalizedData = []
    for i in range (lenOriginal):
        normalizedData.append((originalData.iloc[i]-min2norm)/(max2norm-min2norm))    
    return pd.DataFrame(normalizedData)

# %%
# originalData and forecastedData should be Column Vectored DataFrames
def minmaxDeNorm( originalData, forecastedData, lenTrainValidation):
    max2norm=max(originalData.iloc[0:lenTrainValidation,0])
    min2norm=min(originalData.iloc[0:lenTrainValidation,0])
    lenOriginal=len(originalData)
    denormalizedData=[]    
    for i in range (lenOriginal):
        denormalizedData.append((forecastedData.iloc[i]*(max2norm-min2norm))+min2norm)  
    return pd.DataFrame(denormalizedData)

# %%
# Timeseries_Data and forecasted_value should be Column Vectored DataFrames
def findRMSE( Timeseries_Data, forecasted_value,lenTrainValidation):
    l=Timeseries_Data.shape[0]
    lenTest=l-lenTrainValidation
    trainRMSE=0;
    for i in range (lenTrainValidation):
        trainRMSE=trainRMSE+np.power((forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0]),2) 
    trainRMSE=np.sqrt(trainRMSE/lenTrainValidation)

    testRMSE=0;
    for i in range (lenTrainValidation,l,1):
        testRMSE=testRMSE+np.power((forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0]),2)
    testRMSE=np.sqrt(testRMSE/lenTest)
    return trainRMSE, testRMSE

# %%
# Timeseries_Data and forecasted_value should be Column Vectored DataFrames
def findMAE( Timeseries_Data, forecasted_value,lenTrainValidation):
    l=Timeseries_Data.shape[0]
    lenTest=l-lenTrainValidation
    trainMAE=0;
    for i in range (lenTrainValidation):
        trainMAE=trainMAE+np.abs(forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0]) 
    trainMAE=(trainMAE/(lenTrainValidation));

    testMAE=0;
    for i in range (lenTrainValidation,l,1):
        testMAE=testMAE+np.abs(forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0])
    testMAE=(testMAE/lenTest);
    return trainMAE, testMAE

# %%
def Find_Features_LSTM(x,y,lenValid,lenTest):
    NOP=len(y)
    n_features=1
    lenTrain=NOP-lenValid-lenTest
    LagLength=x.shape[1]
    xTrain=x[0:lenTrain,:]
    xValid=x[lenTrain:(lenTrain+lenValid),:]
    xTest=x[(lenTrain+lenValid):NOP,:]
    yTrain=y[0:lenTrain,0]
    yValid=y[lenTrain:(lenTrain+lenValid),0]
    yTest=y[(lenTrain+lenValid):NOP,0]
    model1 = Sequential()
    model1.add(LSTM(256, activation='tanh', input_shape=(LagLength,n_features),kernel_initializer="he_normal",name="layer1"))
    model1.add(Flatten())
    model1.add(Dense(16, activation='relu',kernel_initializer="he_normal"))
    model1.add(Dense(1,activation='linear'))
    checkpoint_filepath = './'
    cp1=ModelCheckpoint(checkpoint_filepath,save_best_only='True')
    model1.compile(loss=MeanSquaredError(),optimizer=Adam(learning_rate=0.01),metrics=[RootMeanSquaredError()])
    # fit
    model1.fit(xTrain, yTrain,validation_data=(xValid,yValid), epochs=100, verbose=1,batch_size=16)
    yhatNorm=model1.predict(x).flatten().reshape(x.shape[0],1)
    feature_extractor = Model(inputs=model1.inputs, outputs=model1.get_layer(name="layer1").output)
    features = pd.DataFrame(feature_extractor(x))
    return features

# %%
def Find_Features_GRU(x,y,lenValid,lenTest):
    NOP=len(y)
    n_features=1
    lenTrain=NOP-lenValid-lenTest
    LagLength=x.shape[1]
    xTrain=x[0:lenTrain,:]
    xValid=x[lenTrain:(lenTrain+lenValid),:]
    xTest=x[(lenTrain+lenValid):NOP,:]
    yTrain=y[0:lenTrain,0]
    yValid=y[lenTrain:(lenTrain+lenValid),0]
    yTest=y[(lenTrain+lenValid):NOP,0]
    model2 = Sequential()
    model2.add(GRU(256, activation='tanh', input_shape=(LagLength,n_features),kernel_initializer="he_normal",name="layer1"))
    model2.add(Flatten())
    model2.add(Dense(16, activation='relu',kernel_initializer="he_normal"))
    model2.add(Dense(1,activation='linear'))
    checkpoint_filepath = './'
    cp2=ModelCheckpoint(checkpoint_filepath,save_best_only='True')
    model2.compile(loss=MeanSquaredError(),optimizer=Adam(learning_rate=0.01),metrics=[RootMeanSquaredError()])
    # fit
    model2.fit(xTrain, yTrain,validation_data=(xValid,yValid), epochs=100, verbose=1,batch_size=16)
    yhatNorm=model2.predict(x).flatten().reshape(x.shape[0],1)
    feature_extractor = Model(inputs=model2.inputs, outputs=model2.get_layer(name="layer1").output)
    features = pd.DataFrame(feature_extractor(x))
    return features

# %%
def Find_Fitness(x,y,lenValid,lenTest,model):
    NOP=y.shape[0]
    lenTrain=NOP-lenValid-lenTest
    xTrain=x[0:(lenTrain+lenValid),:]
    xValid=x[lenTrain:(lenTrain+lenValid),:]
    xTest=x[(lenTrain+lenValid):NOP,:]
    yTrain=y[0:(lenTrain+lenValid),0]
    yValid=y[lenTrain:(lenTrain+lenValid),0]
    yTest=y[(lenTrain+lenValid):NOP,0]
    model.fit(xTrain, yTrain)
    yhatNorm=model.predict(x).flatten().reshape(x.shape[0],1)
    return pd.DataFrame(yhatNorm)

# %%
#Read the Time Series Dataset
Timeseries_Data=pd.read_csv('AQI.csv',header=None)
LagLength=24
h=1
NumberOfRepeatitions=2
lt=Timeseries_Data.shape[0]
lenTrain=int(round(lt*0.6))
lenValidation=int(round(lt*0.2))
lenTest=int(lt-lenTrain-lenValidation)
# NORMALIZE THE DATA
normalizedData=minmaxNorm(Timeseries_Data,lenTrain+lenValidation);
# Transform the Time Series into Patterns Using Sliding Window
X, y = get_Patterns(normalizedData, LagLength, h)
LSTMFeatures=Find_Features_LSTM(X,y,lenValidation,lenTest)
GRUFeatures=Find_Features_GRU(X,y,lenValidation,lenTest)
X=np.array(np.hstack((LSTMFeatures,GRUFeatures)))
#X = SelectKBest(score_func=f_regression, k=24).fit_transform(X, y)
#pca = PCA(n_components=24)
#X = pca.fit_transform(X)
MeanAccuracyT=pd.DataFrame()
StdAccuracyT=pd.DataFrame()
model=RandomForestRegressor()
name='9.RandomForestRegressor'
file1='./'+str(name)+"_Accuracy.xlsx"
file2='./'+str(name)+"_Forecasts.xlsx"
Forecasts=pd.DataFrame()
Accuracy=pd.DataFrame()
ynorm1=Find_Fitness(X,y,lenValidation,lenTest,model)
ynorm=pd.DataFrame(normalizedData.iloc[0:LagLength,0])
ynorm=ynorm.append(ynorm1,ignore_index = True)
yhat=minmaxDeNorm(Timeseries_Data, ynorm, lenTrain+lenValidation)
Accuracy.loc[0,0],Accuracy.loc[0,1]=findRMSE( Timeseries_Data,yhat,lenTrain+lenValidation)
Accuracy.loc[0,2],Accuracy.loc[0,3]=findMAE( Timeseries_Data,yhat,lenTrain+lenValidation)
Forecasts=Forecasts.append(yhat.T,ignore_index = True)
Accuracy.to_excel(file1,sheet_name='Accuracy',index=False)
Forecasts.T.to_excel(file2,sheet_name='Forecasts',index=False)
Accuracy
# Out:
# Epoch 1/100
# 18/18 [==============================] - 12s 243ms/step - loss: 1.9069 - root_mean_squared_error: 1.3809 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0479
# Epoch 2/100
# 18/18 [==============================] - 2s 122ms/step - loss: 0.0030 - root_mean_squared_error: 0.0550 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0641
# Epoch 3/100
# 18/18 [==============================] - 2s 125ms/step - loss: 0.0021 - root_mean_squared_error: 0.0457 - val_loss: 4.7226e-04 - val_root_mean_squared_error: 0.0217
# Epoch 4/100
# 18/18 [==============================] - 2s 123ms/step - loss: 0.0011 - root_mean_squared_error: 0.0334 - val_loss: 2.3016e-04 - val_root_mean_squared_error: 0.0152
# Epoch 5/100
# 18/18 [==============================] - 2s 124ms/step - loss: 6.0656e-04 - root_mean_squared_error: 0.0246 - val_loss: 2.4385e-04 - val_root_mean_squared_error: 0.0156
# Epoch 6/100
# 18/18 [==============================] - 2s 125ms/step - loss: 4.8859e-04 - root_mean_squared_error: 0.0221 - val_loss: 3.5542e-04 - val_root_mean_squared_error: 0.0189
# Epoch 7/100
# 18/18 [==============================] - 2s 122ms/step - loss: 4.6635e-04 - root_mean_squared_error: 0.0216 - val_loss: 6.9648e-04 - val_root_mean_squared_error: 0.0264
# Epoch 8/100
# 18/18 [==============================] - 2s 124ms/step - loss: 7.2368e-04 - root_mean_squared_error: 0.0269 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0523
# Epoch 9/100
# 18/18 [==============================] - 2s 122ms/step - loss: 0.0015 - root_mean_squared_error: 0.0385 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0322
# Epoch 10/100
# 18/18 [==============================] - 3s 149ms/step - loss: 9.9544e-04 - root_mean_squared_error: 0.0316 - val_loss: 2.1065e-04 - val_root_mean_squared_error: 0.0145
# Epoch 11/100
# 18/18 [==============================] - 3s 157ms/step - loss: 6.9438e-04 - root_mean_squared_error: 0.0264 - val_loss: 3.9697e-04 - val_root_mean_squared_error: 0.0199
# Epoch 12/100
# 18/18 [==============================] - 2s 124ms/step - loss: 4.5811e-04 - root_mean_squared_error: 0.0214 - val_loss: 2.2272e-04 - val_root_mean_squared_error: 0.0149
# Epoch 13/100
# 18/18 [==============================] - 2s 124ms/step - loss: 4.3701e-04 - root_mean_squared_error: 0.0209 - val_loss: 3.2654e-04 - val_root_mean_squared_error: 0.0181
# Epoch 14/100
# 18/18 [==============================] - 2s 135ms/step - loss: 3.9741e-04 - root_mean_squared_error: 0.0199 - val_loss: 2.6718e-04 - val_root_mean_squared_error: 0.0163
# Epoch 15/100
# 18/18 [==============================] - 2s 122ms/step - loss: 3.4643e-04 - root_mean_squared_error: 0.0186 - val_loss: 3.3317e-04 - val_root_mean_squared_error: 0.0183
# Epoch 16/100
# 18/18 [==============================] - 3s 180ms/step - loss: 4.2779e-04 - root_mean_squared_error: 0.0207 - val_loss: 7.1218e-04 - val_root_mean_squared_error: 0.0267
# Epoch 17/100
# 18/18 [==============================] - 3s 193ms/step - loss: 3.6651e-04 - root_mean_squared_error: 0.0191 - val_loss: 2.5582e-04 - val_root_mean_squared_error: 0.0160
# Epoch 18/100
# 18/18 [==============================] - 3s 182ms/step - loss: 2.5373e-04 - root_mean_squared_error: 0.0159 - val_loss: 2.6536e-04 - val_root_mean_squared_error: 0.0163
# Epoch 19/100
# 18/18 [==============================] - 3s 194ms/step - loss: 3.0726e-04 - root_mean_squared_error: 0.0175 - val_loss: 2.7225e-04 - val_root_mean_squared_error: 0.0165
# Epoch 20/100
# 18/18 [==============================] - 3s 199ms/step - loss: 3.4529e-04 - root_mean_squared_error: 0.0186 - val_loss: 2.7037e-04 - val_root_mean_squared_error: 0.0164
# Epoch 21/100
# 18/18 [==============================] - 3s 189ms/step - loss: 7.3495e-04 - root_mean_squared_error: 0.0271 - val_loss: 4.6310e-04 - val_root_mean_squared_error: 0.0215
# Epoch 22/100
# 18/18 [==============================] - 4s 205ms/step - loss: 6.4625e-04 - root_mean_squared_error: 0.0254 - val_loss: 2.2582e-04 - val_root_mean_squared_error: 0.0150
# Epoch 23/100
# 18/18 [==============================] - 4s 220ms/step - loss: 2.8189e-04 - root_mean_squared_error: 0.0168 - val_loss: 3.1380e-04 - val_root_mean_squared_error: 0.0177
# Epoch 24/100
# 18/18 [==============================] - 4s 198ms/step - loss: 3.8242e-04 - root_mean_squared_error: 0.0196 - val_loss: 3.9181e-04 - val_root_mean_squared_error: 0.0198
# Epoch 25/100
# 18/18 [==============================] - 3s 176ms/step - loss: 3.7847e-04 - root_mean_squared_error: 0.0195 - val_loss: 3.1582e-04 - val_root_mean_squared_error: 0.0178
# Epoch 26/100
# 18/18 [==============================] - 3s 196ms/step - loss: 3.2727e-04 - root_mean_squared_error: 0.0181 - val_loss: 2.7030e-04 - val_root_mean_squared_error: 0.0164
# Epoch 27/100
# 18/18 [==============================] - 4s 234ms/step - loss: 6.9926e-04 - root_mean_squared_error: 0.0264 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0402
# Epoch 28/100
# 18/18 [==============================] - 3s 193ms/step - loss: 8.2535e-04 - root_mean_squared_error: 0.0287 - val_loss: 4.7125e-04 - val_root_mean_squared_error: 0.0217
# Epoch 29/100
# 18/18 [==============================] - 3s 177ms/step - loss: 3.2792e-04 - root_mean_squared_error: 0.0181 - val_loss: 4.0172e-04 - val_root_mean_squared_error: 0.0200
# Epoch 30/100
# 18/18 [==============================] - 3s 192ms/step - loss: 3.0735e-04 - root_mean_squared_error: 0.0175 - val_loss: 3.3383e-04 - val_root_mean_squared_error: 0.0183
# Epoch 31/100
# 18/18 [==============================] - 3s 190ms/step - loss: 2.6244e-04 - root_mean_squared_error: 0.0162 - val_loss: 2.5873e-04 - val_root_mean_squared_error: 0.0161
# Epoch 32/100
# 18/18 [==============================] - 3s 175ms/step - loss: 2.8868e-04 - root_mean_squared_error: 0.0170 - val_loss: 3.9836e-04 - val_root_mean_squared_error: 0.0200
# Epoch 33/100
# 18/18 [==============================] - 4s 200ms/step - loss: 3.8562e-04 - root_mean_squared_error: 0.0196 - val_loss: 7.9846e-04 - val_root_mean_squared_error: 0.0283
# Epoch 34/100
# 18/18 [==============================] - 4s 199ms/step - loss: 3.4887e-04 - root_mean_squared_error: 0.0187 - val_loss: 3.2638e-04 - val_root_mean_squared_error: 0.0181
# Epoch 35/100
# 18/18 [==============================] - 3s 190ms/step - loss: 3.4228e-04 - root_mean_squared_error: 0.0185 - val_loss: 4.4268e-04 - val_root_mean_squared_error: 0.0210
# Epoch 36/100
# 18/18 [==============================] - 3s 197ms/step - loss: 3.3183e-04 - root_mean_squared_error: 0.0182 - val_loss: 2.5694e-04 - val_root_mean_squared_error: 0.0160
# Epoch 37/100
# 18/18 [==============================] - 3s 187ms/step - loss: 4.3831e-04 - root_mean_squared_error: 0.0209 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0395
# Epoch 38/100
# 18/18 [==============================] - 4s 198ms/step - loss: 7.2126e-04 - root_mean_squared_error: 0.0269 - val_loss: 3.2034e-04 - val_root_mean_squared_error: 0.0179
# Epoch 39/100
# 18/18 [==============================] - 3s 196ms/step - loss: 5.4848e-04 - root_mean_squared_error: 0.0234 - val_loss: 4.1629e-04 - val_root_mean_squared_error: 0.0204
# Epoch 40/100
# 18/18 [==============================] - 3s 182ms/step - loss: 3.9831e-04 - root_mean_squared_error: 0.0200 - val_loss: 2.5298e-04 - val_root_mean_squared_error: 0.0159
# Epoch 41/100
# 18/18 [==============================] - 4s 240ms/step - loss: 4.2774e-04 - root_mean_squared_error: 0.0207 - val_loss: 8.0828e-04 - val_root_mean_squared_error: 0.0284
# Epoch 42/100
# 18/18 [==============================] - 4s 212ms/step - loss: 4.8359e-04 - root_mean_squared_error: 0.0220 - val_loss: 3.2948e-04 - val_root_mean_squared_error: 0.0182
# Epoch 43/100
# 18/18 [==============================] - 4s 197ms/step - loss: 3.2818e-04 - root_mean_squared_error: 0.0181 - val_loss: 3.7539e-04 - val_root_mean_squared_error: 0.0194
# Epoch 44/100
# 18/18 [==============================] - 4s 236ms/step - loss: 4.9876e-04 - root_mean_squared_error: 0.0223 - val_loss: 6.0706e-04 - val_root_mean_squared_error: 0.0246
# Epoch 45/100
# 18/18 [==============================] - 4s 239ms/step - loss: 3.5068e-04 - root_mean_squared_error: 0.0187 - val_loss: 3.4709e-04 - val_root_mean_squared_error: 0.0186
# Epoch 46/100
# 18/18 [==============================] - 5s 274ms/step - loss: 2.3746e-04 - root_mean_squared_error: 0.0154 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0317
# Epoch 47/100
# 18/18 [==============================] - 5s 264ms/step - loss: 4.3503e-04 - root_mean_squared_error: 0.0209 - val_loss: 2.6967e-04 - val_root_mean_squared_error: 0.0164
# Epoch 48/100
# 18/18 [==============================] - 4s 238ms/step - loss: 3.4936e-04 - root_mean_squared_error: 0.0187 - val_loss: 2.8121e-04 - val_root_mean_squared_error: 0.0168
# Epoch 49/100
# 18/18 [==============================] - 7s 380ms/step - loss: 3.1475e-04 - root_mean_squared_error: 0.0177 - val_loss: 2.9837e-04 - val_root_mean_squared_error: 0.0173
# Epoch 50/100
# 18/18 [==============================] - 7s 424ms/step - loss: 3.9730e-04 - root_mean_squared_error: 0.0199 - val_loss: 4.2466e-04 - val_root_mean_squared_error: 0.0206
# Epoch 51/100
# 18/18 [==============================] - 5s 276ms/step - loss: 3.1199e-04 - root_mean_squared_error: 0.0177 - val_loss: 6.6355e-04 - val_root_mean_squared_error: 0.0258
# Epoch 52/100
# 18/18 [==============================] - 5s 305ms/step - loss: 4.1906e-04 - root_mean_squared_error: 0.0205 - val_loss: 3.6778e-04 - val_root_mean_squared_error: 0.0192
# Epoch 53/100
# 18/18 [==============================] - 4s 230ms/step - loss: 3.6911e-04 - root_mean_squared_error: 0.0192 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0352
# Epoch 54/100
# 18/18 [==============================] - 4s 227ms/step - loss: 5.7457e-04 - root_mean_squared_error: 0.0240 - val_loss: 2.6370e-04 - val_root_mean_squared_error: 0.0162
# Epoch 55/100
# 18/18 [==============================] - 4s 222ms/step - loss: 3.7367e-04 - root_mean_squared_error: 0.0193 - val_loss: 6.5560e-04 - val_root_mean_squared_error: 0.0256
# Epoch 56/100
# 18/18 [==============================] - 6s 337ms/step - loss: 5.3077e-04 - root_mean_squared_error: 0.0230 - val_loss: 9.7101e-04 - val_root_mean_squared_error: 0.0312
# Epoch 57/100
# 18/18 [==============================] - 6s 324ms/step - loss: 4.6283e-04 - root_mean_squared_error: 0.0215 - val_loss: 3.5925e-04 - val_root_mean_squared_error: 0.0190
# Epoch 58/100
# 18/18 [==============================] - 6s 369ms/step - loss: 7.0028e-04 - root_mean_squared_error: 0.0265 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0410
# Epoch 59/100
# 18/18 [==============================] - 5s 253ms/step - loss: 6.3175e-04 - root_mean_squared_error: 0.0251 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0373
# Epoch 60/100
# 18/18 [==============================] - 5s 294ms/step - loss: 7.5578e-04 - root_mean_squared_error: 0.0275 - val_loss: 6.9136e-04 - val_root_mean_squared_error: 0.0263
# Epoch 61/100
# 18/18 [==============================] - 4s 231ms/step - loss: 4.2690e-04 - root_mean_squared_error: 0.0207 - val_loss: 5.2246e-04 - val_root_mean_squared_error: 0.0229
# Epoch 62/100
# 18/18 [==============================] - 4s 233ms/step - loss: 4.7917e-04 - root_mean_squared_error: 0.0219 - val_loss: 5.3937e-04 - val_root_mean_squared_error: 0.0232
# Epoch 63/100
# 18/18 [==============================] - 4s 198ms/step - loss: 3.3460e-04 - root_mean_squared_error: 0.0183 - val_loss: 3.3214e-04 - val_root_mean_squared_error: 0.0182
# Epoch 64/100
# 18/18 [==============================] - 4s 211ms/step - loss: 3.5779e-04 - root_mean_squared_error: 0.0189 - val_loss: 6.7122e-04 - val_root_mean_squared_error: 0.0259
# Epoch 65/100
# 18/18 [==============================] - 5s 259ms/step - loss: 4.3112e-04 - root_mean_squared_error: 0.0208 - val_loss: 3.8850e-04 - val_root_mean_squared_error: 0.0197
# Epoch 66/100
# 18/18 [==============================] - 5s 273ms/step - loss: 2.7899e-04 - root_mean_squared_error: 0.0167 - val_loss: 3.8565e-04 - val_root_mean_squared_error: 0.0196
# Epoch 67/100
# 18/18 [==============================] - 4s 215ms/step - loss: 3.2288e-04 - root_mean_squared_error: 0.0180 - val_loss: 4.2189e-04 - val_root_mean_squared_error: 0.0205
# Epoch 68/100
# 18/18 [==============================] - 4s 220ms/step - loss: 3.1156e-04 - root_mean_squared_error: 0.0177 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0328
# Epoch 69/100
# 18/18 [==============================] - 3s 190ms/step - loss: 4.8060e-04 - root_mean_squared_error: 0.0219 - val_loss: 2.7425e-04 - val_root_mean_squared_error: 0.0166
# Epoch 70/100
# 18/18 [==============================] - 3s 192ms/step - loss: 5.4854e-04 - root_mean_squared_error: 0.0234 - val_loss: 6.7508e-04 - val_root_mean_squared_error: 0.0260
# Epoch 71/100
# 18/18 [==============================] - 3s 192ms/step - loss: 5.1800e-04 - root_mean_squared_error: 0.0228 - val_loss: 2.6853e-04 - val_root_mean_squared_error: 0.0164
# Epoch 72/100
# 18/18 [==============================] - 4s 198ms/step - loss: 2.7649e-04 - root_mean_squared_error: 0.0166 - val_loss: 3.3520e-04 - val_root_mean_squared_error: 0.0183
# Epoch 73/100
# 18/18 [==============================] - 3s 197ms/step - loss: 4.4571e-04 - root_mean_squared_error: 0.0211 - val_loss: 7.2434e-04 - val_root_mean_squared_error: 0.0269
# Epoch 74/100
# 18/18 [==============================] - 3s 193ms/step - loss: 4.1569e-04 - root_mean_squared_error: 0.0204 - val_loss: 2.6107e-04 - val_root_mean_squared_error: 0.0162
# Epoch 75/100
# 18/18 [==============================] - 4s 200ms/step - loss: 2.6532e-04 - root_mean_squared_error: 0.0163 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0347
# Epoch 76/100
# 18/18 [==============================] - 3s 179ms/step - loss: 5.9251e-04 - root_mean_squared_error: 0.0243 - val_loss: 2.9001e-04 - val_root_mean_squared_error: 0.0170
# Epoch 77/100
# 18/18 [==============================] - 4s 205ms/step - loss: 3.9137e-04 - root_mean_squared_error: 0.0198 - val_loss: 3.3930e-04 - val_root_mean_squared_error: 0.0184
# Epoch 78/100
# 18/18 [==============================] - 4s 213ms/step - loss: 3.7854e-04 - root_mean_squared_error: 0.0195 - val_loss: 8.0407e-04 - val_root_mean_squared_error: 0.0284
# Epoch 79/100
# 18/18 [==============================] - 4s 204ms/step - loss: 4.6913e-04 - root_mean_squared_error: 0.0217 - val_loss: 4.1182e-04 - val_root_mean_squared_error: 0.0203
# Epoch 80/100
# 18/18 [==============================] - 4s 225ms/step - loss: 2.8934e-04 - root_mean_squared_error: 0.0170 - val_loss: 3.2944e-04 - val_root_mean_squared_error: 0.0182
# Epoch 81/100
# 18/18 [==============================] - 4s 224ms/step - loss: 2.6371e-04 - root_mean_squared_error: 0.0162 - val_loss: 3.2909e-04 - val_root_mean_squared_error: 0.0181
# Epoch 82/100
# 18/18 [==============================] - 4s 198ms/step - loss: 3.0042e-04 - root_mean_squared_error: 0.0173 - val_loss: 2.6838e-04 - val_root_mean_squared_error: 0.0164
# Epoch 83/100
# 18/18 [==============================] - 3s 192ms/step - loss: 3.0100e-04 - root_mean_squared_error: 0.0173 - val_loss: 3.2455e-04 - val_root_mean_squared_error: 0.0180
# Epoch 84/100
# 18/18 [==============================] - 3s 184ms/step - loss: 3.0010e-04 - root_mean_squared_error: 0.0173 - val_loss: 3.4387e-04 - val_root_mean_squared_error: 0.0185
# Epoch 85/100
# 18/18 [==============================] - 3s 182ms/step - loss: 3.1439e-04 - root_mean_squared_error: 0.0177 - val_loss: 3.1861e-04 - val_root_mean_squared_error: 0.0178
# Epoch 86/100
# 18/18 [==============================] - 4s 202ms/step - loss: 3.0407e-04 - root_mean_squared_error: 0.0174 - val_loss: 2.7951e-04 - val_root_mean_squared_error: 0.0167
# Epoch 87/100
# 18/18 [==============================] - 3s 189ms/step - loss: 3.6988e-04 - root_mean_squared_error: 0.0192 - val_loss: 5.3162e-04 - val_root_mean_squared_error: 0.0231
# Epoch 88/100
# 18/18 [==============================] - 3s 192ms/step - loss: 3.8916e-04 - root_mean_squared_error: 0.0197 - val_loss: 3.2366e-04 - val_root_mean_squared_error: 0.0180
# Epoch 89/100
# 18/18 [==============================] - 3s 187ms/step - loss: 5.2185e-04 - root_mean_squared_error: 0.0228 - val_loss: 8.2031e-04 - val_root_mean_squared_error: 0.0286
# Epoch 90/100
# 18/18 [==============================] - 3s 197ms/step - loss: 5.7032e-04 - root_mean_squared_error: 0.0239 - val_loss: 3.1844e-04 - val_root_mean_squared_error: 0.0178
# Epoch 91/100
# 18/18 [==============================] - 4s 201ms/step - loss: 5.0642e-04 - root_mean_squared_error: 0.0225 - val_loss: 2.9271e-04 - val_root_mean_squared_error: 0.0171
# Epoch 92/100
# 18/18 [==============================] - 3s 188ms/step - loss: 3.8441e-04 - root_mean_squared_error: 0.0196 - val_loss: 2.7712e-04 - val_root_mean_squared_error: 0.0166
# Epoch 93/100
# 18/18 [==============================] - 4s 222ms/step - loss: 5.4430e-04 - root_mean_squared_error: 0.0233 - val_loss: 3.1944e-04 - val_root_mean_squared_error: 0.0179
# Epoch 94/100
# 18/18 [==============================] - 4s 215ms/step - loss: 4.3205e-04 - root_mean_squared_error: 0.0208 - val_loss: 3.5386e-04 - val_root_mean_squared_error: 0.0188
# Epoch 95/100
# 18/18 [==============================] - 4s 205ms/step - loss: 3.3085e-04 - root_mean_squared_error: 0.0182 - val_loss: 2.7517e-04 - val_root_mean_squared_error: 0.0166
# Epoch 96/100
# 18/18 [==============================] - 4s 201ms/step - loss: 4.4048e-04 - root_mean_squared_error: 0.0210 - val_loss: 3.1594e-04 - val_root_mean_squared_error: 0.0178
# Epoch 97/100
# 18/18 [==============================] - 3s 184ms/step - loss: 3.7412e-04 - root_mean_squared_error: 0.0193 - val_loss: 3.5625e-04 - val_root_mean_squared_error: 0.0189
# Epoch 98/100
# 18/18 [==============================] - 4s 210ms/step - loss: 2.5953e-04 - root_mean_squared_error: 0.0161 - val_loss: 4.0634e-04 - val_root_mean_squared_error: 0.0202
# Epoch 99/100
# 18/18 [==============================] - 3s 193ms/step - loss: 3.0062e-04 - root_mean_squared_error: 0.0173 - val_loss: 2.8015e-04 - val_root_mean_squared_error: 0.0167
# Epoch 100/100
# 18/18 [==============================] - 3s 180ms/step - loss: 3.4266e-04 - root_mean_squared_error: 0.0185 - val_loss: 9.0148e-04 - val_root_mean_squared_error: 0.0300
# 15/15 [==============================] - 10s 108ms/step
# Epoch 1/100
# 18/18 [==============================] - 13s 202ms/step - loss: 1.0644 - root_mean_squared_error: 1.0317 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1434
# Epoch 2/100
# 18/18 [==============================] - 2s 92ms/step - loss: 0.0225 - root_mean_squared_error: 0.1498 - val_loss: 3.7363e-04 - val_root_mean_squared_error: 0.0193
# Epoch 3/100
# 18/18 [==============================] - 1s 79ms/step - loss: 0.0040 - root_mean_squared_error: 0.0629 - val_loss: 4.0143e-04 - val_root_mean_squared_error: 0.0200
# Epoch 4/100
# 18/18 [==============================] - 1s 77ms/step - loss: 9.0951e-04 - root_mean_squared_error: 0.0302 - val_loss: 2.7249e-04 - val_root_mean_squared_error: 0.0165
# Epoch 5/100
# 18/18 [==============================] - 1s 75ms/step - loss: 5.9019e-04 - root_mean_squared_error: 0.0243 - val_loss: 4.0498e-04 - val_root_mean_squared_error: 0.0201
# Epoch 6/100
# 18/18 [==============================] - 1s 77ms/step - loss: 4.6471e-04 - root_mean_squared_error: 0.0216 - val_loss: 2.6112e-04 - val_root_mean_squared_error: 0.0162
# Epoch 7/100
# 18/18 [==============================] - 2s 96ms/step - loss: 3.8622e-04 - root_mean_squared_error: 0.0197 - val_loss: 5.0927e-04 - val_root_mean_squared_error: 0.0226
# Epoch 8/100
# 18/18 [==============================] - 2s 107ms/step - loss: 4.6606e-04 - root_mean_squared_error: 0.0216 - val_loss: 2.9162e-04 - val_root_mean_squared_error: 0.0171
# Epoch 9/100
# 18/18 [==============================] - 1s 70ms/step - loss: 2.9440e-04 - root_mean_squared_error: 0.0172 - val_loss: 5.0494e-04 - val_root_mean_squared_error: 0.0225
# Epoch 10/100
# 18/18 [==============================] - 1s 68ms/step - loss: 3.9224e-04 - root_mean_squared_error: 0.0198 - val_loss: 6.6253e-04 - val_root_mean_squared_error: 0.0257
# Epoch 11/100
# 18/18 [==============================] - 1s 68ms/step - loss: 4.4053e-04 - root_mean_squared_error: 0.0210 - val_loss: 2.9936e-04 - val_root_mean_squared_error: 0.0173
# Epoch 12/100
# 18/18 [==============================] - 1s 68ms/step - loss: 2.9802e-04 - root_mean_squared_error: 0.0173 - val_loss: 3.1909e-04 - val_root_mean_squared_error: 0.0179
# Epoch 13/100
# 18/18 [==============================] - 1s 72ms/step - loss: 3.2757e-04 - root_mean_squared_error: 0.0181 - val_loss: 2.9147e-04 - val_root_mean_squared_error: 0.0171
# Epoch 14/100
# 18/18 [==============================] - 2s 90ms/step - loss: 3.5775e-04 - root_mean_squared_error: 0.0189 - val_loss: 6.8213e-04 - val_root_mean_squared_error: 0.0261
# Epoch 15/100
# 18/18 [==============================] - 2s 116ms/step - loss: 3.7125e-04 - root_mean_squared_error: 0.0193 - val_loss: 4.5075e-04 - val_root_mean_squared_error: 0.0212
# Epoch 16/100
# 18/18 [==============================] - 2s 96ms/step - loss: 3.4411e-04 - root_mean_squared_error: 0.0186 - val_loss: 2.8050e-04 - val_root_mean_squared_error: 0.0167
# Epoch 17/100
# 18/18 [==============================] - 2s 94ms/step - loss: 3.4226e-04 - root_mean_squared_error: 0.0185 - val_loss: 9.1880e-04 - val_root_mean_squared_error: 0.0303
# Epoch 18/100
# 18/18 [==============================] - 1s 83ms/step - loss: 4.5423e-04 - root_mean_squared_error: 0.0213 - val_loss: 3.5381e-04 - val_root_mean_squared_error: 0.0188
# Epoch 19/100
# 18/18 [==============================] - 2s 90ms/step - loss: 3.2725e-04 - root_mean_squared_error: 0.0181 - val_loss: 2.9071e-04 - val_root_mean_squared_error: 0.0171
# Epoch 20/100
# 18/18 [==============================] - 1s 82ms/step - loss: 2.6166e-04 - root_mean_squared_error: 0.0162 - val_loss: 3.1740e-04 - val_root_mean_squared_error: 0.0178
# Epoch 21/100
# 18/18 [==============================] - 2s 97ms/step - loss: 2.3514e-04 - root_mean_squared_error: 0.0153 - val_loss: 2.8134e-04 - val_root_mean_squared_error: 0.0168
# Epoch 22/100
# 18/18 [==============================] - 2s 87ms/step - loss: 2.4914e-04 - root_mean_squared_error: 0.0158 - val_loss: 4.6843e-04 - val_root_mean_squared_error: 0.0216
# Epoch 23/100
# 18/18 [==============================] - 2s 90ms/step - loss: 4.0155e-04 - root_mean_squared_error: 0.0200 - val_loss: 4.9617e-04 - val_root_mean_squared_error: 0.0223
# Epoch 24/100
# 18/18 [==============================] - 2s 93ms/step - loss: 2.7768e-04 - root_mean_squared_error: 0.0167 - val_loss: 2.9712e-04 - val_root_mean_squared_error: 0.0172
# Epoch 25/100
# 18/18 [==============================] - 2s 89ms/step - loss: 3.7024e-04 - root_mean_squared_error: 0.0192 - val_loss: 8.7521e-04 - val_root_mean_squared_error: 0.0296
# Epoch 26/100
# 18/18 [==============================] - 2s 95ms/step - loss: 8.2536e-04 - root_mean_squared_error: 0.0287 - val_loss: 8.8236e-04 - val_root_mean_squared_error: 0.0297
# Epoch 27/100
# 18/18 [==============================] - 1s 75ms/step - loss: 4.3763e-04 - root_mean_squared_error: 0.0209 - val_loss: 5.7131e-04 - val_root_mean_squared_error: 0.0239
# Epoch 28/100
# 18/18 [==============================] - 1s 74ms/step - loss: 2.7901e-04 - root_mean_squared_error: 0.0167 - val_loss: 3.0821e-04 - val_root_mean_squared_error: 0.0176
# Epoch 29/100
# 18/18 [==============================] - 1s 79ms/step - loss: 3.1538e-04 - root_mean_squared_error: 0.0178 - val_loss: 3.2744e-04 - val_root_mean_squared_error: 0.0181
# Epoch 30/100
# 18/18 [==============================] - 1s 82ms/step - loss: 2.2494e-04 - root_mean_squared_error: 0.0150 - val_loss: 2.9435e-04 - val_root_mean_squared_error: 0.0172
# Epoch 31/100
# 18/18 [==============================] - 1s 83ms/step - loss: 3.1815e-04 - root_mean_squared_error: 0.0178 - val_loss: 9.1909e-04 - val_root_mean_squared_error: 0.0303
# Epoch 32/100
# 18/18 [==============================] - 2s 91ms/step - loss: 3.9828e-04 - root_mean_squared_error: 0.0200 - val_loss: 3.6808e-04 - val_root_mean_squared_error: 0.0192
# Epoch 33/100
# 18/18 [==============================] - 2s 94ms/step - loss: 2.4428e-04 - root_mean_squared_error: 0.0156 - val_loss: 3.5359e-04 - val_root_mean_squared_error: 0.0188
# Epoch 34/100
# 18/18 [==============================] - 2s 93ms/step - loss: 3.0370e-04 - root_mean_squared_error: 0.0174 - val_loss: 4.2205e-04 - val_root_mean_squared_error: 0.0205
# Epoch 35/100
# 18/18 [==============================] - 2s 91ms/step - loss: 3.0449e-04 - root_mean_squared_error: 0.0174 - val_loss: 6.5582e-04 - val_root_mean_squared_error: 0.0256
# Epoch 36/100
# 18/18 [==============================] - 1s 82ms/step - loss: 2.9090e-04 - root_mean_squared_error: 0.0171 - val_loss: 2.8120e-04 - val_root_mean_squared_error: 0.0168
# Epoch 37/100
# 18/18 [==============================] - 2s 85ms/step - loss: 3.7150e-04 - root_mean_squared_error: 0.0193 - val_loss: 4.5043e-04 - val_root_mean_squared_error: 0.0212
# Epoch 38/100
# 18/18 [==============================] - 1s 76ms/step - loss: 6.2042e-04 - root_mean_squared_error: 0.0249 - val_loss: 3.2565e-04 - val_root_mean_squared_error: 0.0180
# Epoch 39/100
# 18/18 [==============================] - 1s 78ms/step - loss: 3.4492e-04 - root_mean_squared_error: 0.0186 - val_loss: 6.5514e-04 - val_root_mean_squared_error: 0.0256
# Epoch 40/100
# 18/18 [==============================] - 1s 79ms/step - loss: 3.7422e-04 - root_mean_squared_error: 0.0193 - val_loss: 2.9050e-04 - val_root_mean_squared_error: 0.0170
# Epoch 41/100
# 18/18 [==============================] - 1s 81ms/step - loss: 3.0248e-04 - root_mean_squared_error: 0.0174 - val_loss: 5.1671e-04 - val_root_mean_squared_error: 0.0227
# Epoch 42/100
# 18/18 [==============================] - 1s 78ms/step - loss: 2.6567e-04 - root_mean_squared_error: 0.0163 - val_loss: 5.2076e-04 - val_root_mean_squared_error: 0.0228
# Epoch 43/100
# 18/18 [==============================] - 1s 80ms/step - loss: 4.3566e-04 - root_mean_squared_error: 0.0209 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0323
# Epoch 44/100
# 18/18 [==============================] - 1s 75ms/step - loss: 4.3743e-04 - root_mean_squared_error: 0.0209 - val_loss: 2.7440e-04 - val_root_mean_squared_error: 0.0166
# Epoch 45/100
# 18/18 [==============================] - 1s 77ms/step - loss: 2.6044e-04 - root_mean_squared_error: 0.0161 - val_loss: 4.8876e-04 - val_root_mean_squared_error: 0.0221
# Epoch 46/100
# 18/18 [==============================] - 1s 79ms/step - loss: 2.9800e-04 - root_mean_squared_error: 0.0173 - val_loss: 8.4831e-04 - val_root_mean_squared_error: 0.0291
# Epoch 47/100
# 18/18 [==============================] - 1s 79ms/step - loss: 2.6468e-04 - root_mean_squared_error: 0.0163 - val_loss: 2.9226e-04 - val_root_mean_squared_error: 0.0171
# Epoch 48/100
# 18/18 [==============================] - 1s 77ms/step - loss: 2.4770e-04 - root_mean_squared_error: 0.0157 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0368
# Epoch 49/100
# 18/18 [==============================] - 1s 77ms/step - loss: 7.3047e-04 - root_mean_squared_error: 0.0270 - val_loss: 5.1667e-04 - val_root_mean_squared_error: 0.0227
# Epoch 50/100
# 18/18 [==============================] - 1s 78ms/step - loss: 3.1677e-04 - root_mean_squared_error: 0.0178 - val_loss: 3.5220e-04 - val_root_mean_squared_error: 0.0188
# Epoch 51/100
# 18/18 [==============================] - 1s 79ms/step - loss: 3.1930e-04 - root_mean_squared_error: 0.0179 - val_loss: 2.8237e-04 - val_root_mean_squared_error: 0.0168
# Epoch 52/100
# 18/18 [==============================] - 2s 83ms/step - loss: 2.3347e-04 - root_mean_squared_error: 0.0153 - val_loss: 2.6814e-04 - val_root_mean_squared_error: 0.0164
# Epoch 53/100
# 18/18 [==============================] - 1s 76ms/step - loss: 2.1334e-04 - root_mean_squared_error: 0.0146 - val_loss: 3.2928e-04 - val_root_mean_squared_error: 0.0181
# Epoch 54/100
# 18/18 [==============================] - 1s 79ms/step - loss: 4.2806e-04 - root_mean_squared_error: 0.0207 - val_loss: 6.5098e-04 - val_root_mean_squared_error: 0.0255
# Epoch 55/100
# 18/18 [==============================] - 1s 77ms/step - loss: 4.1022e-04 - root_mean_squared_error: 0.0203 - val_loss: 2.9121e-04 - val_root_mean_squared_error: 0.0171
# Epoch 56/100
# 18/18 [==============================] - 1s 77ms/step - loss: 6.7938e-04 - root_mean_squared_error: 0.0261 - val_loss: 3.5220e-04 - val_root_mean_squared_error: 0.0188
# Epoch 57/100
# 18/18 [==============================] - 1s 80ms/step - loss: 0.0012 - root_mean_squared_error: 0.0339 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0322
# Epoch 58/100
# 18/18 [==============================] - 1s 78ms/step - loss: 9.0348e-04 - root_mean_squared_error: 0.0301 - val_loss: 4.8790e-04 - val_root_mean_squared_error: 0.0221
# Epoch 59/100
# 18/18 [==============================] - 1s 78ms/step - loss: 3.3340e-04 - root_mean_squared_error: 0.0183 - val_loss: 3.2423e-04 - val_root_mean_squared_error: 0.0180
# Epoch 60/100
# 18/18 [==============================] - 1s 75ms/step - loss: 2.5674e-04 - root_mean_squared_error: 0.0160 - val_loss: 2.8004e-04 - val_root_mean_squared_error: 0.0167
# Epoch 61/100
# 18/18 [==============================] - 1s 78ms/step - loss: 2.6324e-04 - root_mean_squared_error: 0.0162 - val_loss: 4.7996e-04 - val_root_mean_squared_error: 0.0219
# Epoch 62/100
# 18/18 [==============================] - 1s 77ms/step - loss: 3.6806e-04 - root_mean_squared_error: 0.0192 - val_loss: 3.9332e-04 - val_root_mean_squared_error: 0.0198
# Epoch 63/100
# 18/18 [==============================] - 1s 74ms/step - loss: 4.3869e-04 - root_mean_squared_error: 0.0209 - val_loss: 3.6995e-04 - val_root_mean_squared_error: 0.0192
# Epoch 64/100
# 18/18 [==============================] - 1s 70ms/step - loss: 5.0225e-04 - root_mean_squared_error: 0.0224 - val_loss: 2.5864e-04 - val_root_mean_squared_error: 0.0161
# Epoch 65/100
# 18/18 [==============================] - 1s 73ms/step - loss: 3.7255e-04 - root_mean_squared_error: 0.0193 - val_loss: 6.2113e-04 - val_root_mean_squared_error: 0.0249
# Epoch 66/100
# 18/18 [==============================] - 1s 76ms/step - loss: 4.6190e-04 - root_mean_squared_error: 0.0215 - val_loss: 7.2703e-04 - val_root_mean_squared_error: 0.0270
# Epoch 67/100
# 18/18 [==============================] - 1s 72ms/step - loss: 5.1311e-04 - root_mean_squared_error: 0.0227 - val_loss: 3.0440e-04 - val_root_mean_squared_error: 0.0174
# Epoch 68/100
# 18/18 [==============================] - 1s 72ms/step - loss: 3.3820e-04 - root_mean_squared_error: 0.0184 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0409
# Epoch 69/100
# 18/18 [==============================] - 1s 71ms/step - loss: 5.5579e-04 - root_mean_squared_error: 0.0236 - val_loss: 2.8303e-04 - val_root_mean_squared_error: 0.0168
# Epoch 70/100
# 18/18 [==============================] - 1s 74ms/step - loss: 2.2917e-04 - root_mean_squared_error: 0.0151 - val_loss: 4.4136e-04 - val_root_mean_squared_error: 0.0210
# Epoch 71/100
# 18/18 [==============================] - 1s 73ms/step - loss: 6.3852e-04 - root_mean_squared_error: 0.0253 - val_loss: 3.1826e-04 - val_root_mean_squared_error: 0.0178
# Epoch 72/100
# 18/18 [==============================] - 1s 74ms/step - loss: 4.2182e-04 - root_mean_squared_error: 0.0205 - val_loss: 4.3665e-04 - val_root_mean_squared_error: 0.0209
# Epoch 73/100
# 18/18 [==============================] - 1s 73ms/step - loss: 5.7136e-04 - root_mean_squared_error: 0.0239 - val_loss: 3.3489e-04 - val_root_mean_squared_error: 0.0183
# Epoch 74/100
# 18/18 [==============================] - 1s 74ms/step - loss: 5.0227e-04 - root_mean_squared_error: 0.0224 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0703
# Epoch 75/100
# 18/18 [==============================] - 1s 73ms/step - loss: 0.0019 - root_mean_squared_error: 0.0436 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0506
# Epoch 76/100
# 18/18 [==============================] - 1s 72ms/step - loss: 7.6784e-04 - root_mean_squared_error: 0.0277 - val_loss: 2.8447e-04 - val_root_mean_squared_error: 0.0169
# Epoch 77/100
# 18/18 [==============================] - 1s 73ms/step - loss: 4.6492e-04 - root_mean_squared_error: 0.0216 - val_loss: 4.3525e-04 - val_root_mean_squared_error: 0.0209
# Epoch 78/100
# 18/18 [==============================] - 1s 75ms/step - loss: 4.1631e-04 - root_mean_squared_error: 0.0204 - val_loss: 2.7513e-04 - val_root_mean_squared_error: 0.0166
# Epoch 79/100
# 18/18 [==============================] - 1s 73ms/step - loss: 3.9752e-04 - root_mean_squared_error: 0.0199 - val_loss: 5.7368e-04 - val_root_mean_squared_error: 0.0240
# Epoch 80/100
# 18/18 [==============================] - 1s 74ms/step - loss: 3.1187e-04 - root_mean_squared_error: 0.0177 - val_loss: 6.8535e-04 - val_root_mean_squared_error: 0.0262
# Epoch 81/100
# 18/18 [==============================] - 1s 75ms/step - loss: 3.2398e-04 - root_mean_squared_error: 0.0180 - val_loss: 3.7396e-04 - val_root_mean_squared_error: 0.0193
# Epoch 82/100
# 18/18 [==============================] - 1s 70ms/step - loss: 9.3583e-04 - root_mean_squared_error: 0.0306 - val_loss: 6.9801e-04 - val_root_mean_squared_error: 0.0264
# Epoch 83/100
# 18/18 [==============================] - 1s 68ms/step - loss: 3.5496e-04 - root_mean_squared_error: 0.0188 - val_loss: 8.5520e-04 - val_root_mean_squared_error: 0.0292
# Epoch 84/100
# 18/18 [==============================] - 1s 68ms/step - loss: 4.2626e-04 - root_mean_squared_error: 0.0206 - val_loss: 2.6812e-04 - val_root_mean_squared_error: 0.0164
# Epoch 85/100
# 18/18 [==============================] - 1s 69ms/step - loss: 2.9495e-04 - root_mean_squared_error: 0.0172 - val_loss: 2.7654e-04 - val_root_mean_squared_error: 0.0166
# Epoch 86/100
# 18/18 [==============================] - 1s 70ms/step - loss: 3.6715e-04 - root_mean_squared_error: 0.0192 - val_loss: 5.7082e-04 - val_root_mean_squared_error: 0.0239
# Epoch 87/100
# 18/18 [==============================] - 1s 67ms/step - loss: 4.8173e-04 - root_mean_squared_error: 0.0219 - val_loss: 5.6769e-04 - val_root_mean_squared_error: 0.0238
# Epoch 88/100
# 18/18 [==============================] - 1s 68ms/step - loss: 8.2278e-04 - root_mean_squared_error: 0.0287 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0351
# Epoch 89/100
# 18/18 [==============================] - 1s 69ms/step - loss: 9.9978e-04 - root_mean_squared_error: 0.0316 - val_loss: 9.0131e-04 - val_root_mean_squared_error: 0.0300
# Epoch 90/100
# 18/18 [==============================] - 1s 69ms/step - loss: 4.4750e-04 - root_mean_squared_error: 0.0212 - val_loss: 3.2622e-04 - val_root_mean_squared_error: 0.0181
# Epoch 91/100
# 18/18 [==============================] - 1s 69ms/step - loss: 2.6512e-04 - root_mean_squared_error: 0.0163 - val_loss: 2.9824e-04 - val_root_mean_squared_error: 0.0173
# Epoch 92/100
# 18/18 [==============================] - 1s 68ms/step - loss: 2.9200e-04 - root_mean_squared_error: 0.0171 - val_loss: 2.8159e-04 - val_root_mean_squared_error: 0.0168
# Epoch 93/100
# 18/18 [==============================] - 1s 70ms/step - loss: 5.3075e-04 - root_mean_squared_error: 0.0230 - val_loss: 3.8116e-04 - val_root_mean_squared_error: 0.0195
# Epoch 94/100
# 18/18 [==============================] - 1s 73ms/step - loss: 4.7863e-04 - root_mean_squared_error: 0.0219 - val_loss: 5.6055e-04 - val_root_mean_squared_error: 0.0237
# Epoch 95/100
# 18/18 [==============================] - 1s 74ms/step - loss: 9.1658e-04 - root_mean_squared_error: 0.0303 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0400
# Epoch 96/100
# 18/18 [==============================] - 1s 73ms/step - loss: 6.4247e-04 - root_mean_squared_error: 0.0253 - val_loss: 2.5381e-04 - val_root_mean_squared_error: 0.0159
# Epoch 97/100
# 18/18 [==============================] - 1s 73ms/step - loss: 2.8864e-04 - root_mean_squared_error: 0.0170 - val_loss: 2.6632e-04 - val_root_mean_squared_error: 0.0163
# Epoch 98/100
# 18/18 [==============================] - 1s 72ms/step - loss: 3.0618e-04 - root_mean_squared_error: 0.0175 - val_loss: 6.9447e-04 - val_root_mean_squared_error: 0.0264
# Epoch 99/100
# 18/18 [==============================] - 1s 73ms/step - loss: 2.6407e-04 - root_mean_squared_error: 0.0163 - val_loss: 2.6888e-04 - val_root_mean_squared_error: 0.0164
# Epoch 100/100
# 18/18 [==============================] - 1s 74ms/step - loss: 2.7441e-04 - root_mean_squared_error: 0.0166 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0549
# 15/15 [==============================] - 1s 29ms/step
#           0         1         2       3
# 0  3.499793  6.430519  1.603825  3.4662
