# %%
# Import required packages
import numpy as np
import pandas as pd
import os
import warnings
warnings.filterwarnings("ignore")

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten,LSTM
from keras.callbacks import ModelCheckpoint,EarlyStopping
from keras.metrics import RootMeanSquaredError,mean_absolute_percentage_error
from keras.losses import MeanSquaredError
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model

# %%
# split a univariate time series into patterns
def get_Patterns(TSeries, n_inputs,h):
    X,y,z = pd.DataFrame(np.zeros((len(TSeries)-n_inputs-h+1,n_inputs))), pd.DataFrame(), pd.DataFrame()
    for i in range(len(TSeries)):
        # find the end of this pattern
        end_ix = i + n_inputs + h - 1
        # check if we are beyond the time series
        if end_ix > len(TSeries)-1:
            break
        # gather input and output parts of the pattern
        for j in range(n_inputs):
            X.loc[i,j]=TSeries.iloc[i+j,0]
        i=i+n_inputs
        #y=y.append(TSeries.iloc[end_ix], ignore_index = True)
        y=pd.concat([y, TSeries.iloc[end_ix]], ignore_index=True)
    return pd.DataFrame(X),pd.DataFrame(y)

# %%
# originalData should be a Column Vectored DataFrame
def minmaxNorm(originalData, lenTrainValidation):
    # Maximum Value
    max2norm=max(originalData.iloc[0:lenTrainValidation,0])
    # Minimum Value
    min2norm=min(originalData.iloc[0:lenTrainValidation,0])
    lenOriginal=len(originalData)
    normalizedData=np.zeros(lenOriginal)   
    normalizedData = []
    #Normalize using Min-Max Normalization
    for i in range (lenOriginal):
        normalizedData.append((originalData.iloc[i]-min2norm)/(max2norm-min2norm))    
    return pd.DataFrame(normalizedData)

# %%
# originalData and forecastedData should be Column Vectored DataFrames
def minmaxDeNorm( originalData, forecastedData, lenTrainValidation):
    # Maximum Value
    max2norm=max(originalData.iloc[0:lenTrainValidation,0])
    # Minimum Value
    min2norm=min(originalData.iloc[0:lenTrainValidation,0])
    lenOriginal=len(originalData)
    denormalizedData=[]   
    #De-Normalize using Min-Max Normalization
    for i in range (lenOriginal):
        denormalizedData.append((forecastedData.iloc[i]*(max2norm-min2norm))+min2norm)  
    return pd.DataFrame(denormalizedData)

# %%
# Timeseries_Data and forecasted_value should be Column Vectored DataFrames
def findRMSE( Timeseries_Data, forecasted_value,lenTrainValidation):
    l=Timeseries_Data.shape[0]
    lenTest=l-lenTrainValidation
    trainRMSE=0;
    for i in range (lenTrainValidation):
        trainRMSE=trainRMSE+np.power((forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0]),2) 
    trainRMSE=np.sqrt(trainRMSE/lenTrainValidation)

    testRMSE=0;
    for i in range (lenTrainValidation,l,1):
        testRMSE=testRMSE+np.power((forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0]),2)
    testRMSE=np.sqrt(testRMSE/lenTest)
    return trainRMSE, testRMSE

# %%
# Timeseries_Data and forecasted_value should be Column Vectored DataFrames
def findMAE( Timeseries_Data, forecasted_value,lenTrainValidation):
    l=Timeseries_Data.shape[0]
    lenTest=l-lenTrainValidation
    trainMAE=0;
    for i in range (lenTrainValidation):
        trainMAE=trainMAE+np.abs(forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0]) 
    trainMAE=(trainMAE/(lenTrainValidation));

    testMAE=0;
    for i in range (lenTrainValidation,l,1):
        testMAE=testMAE+np.abs(forecasted_value.iloc[i,0]-Timeseries_Data.iloc[i,0])
    testMAE=(testMAE/lenTest);
    return trainMAE, testMAE

# %%
def Find_Fitness_LSTM(x,y,lenValid,lenTest):
    NOP=len(y)
    n_features=1
    lenTrain=NOP-lenValid-lenTest
    xTrain=x.iloc[0:lenTrain,:]
    xValid=x.iloc[lenTrain:(lenTrain+lenValid),:]
    xTest=x.iloc[(lenTrain+lenValid):NOP,:]
    yTrain=y.iloc[0:lenTrain,0]
    yValid=y.iloc[lenTrain:(lenTrain+lenValid),0]
    yTest=y.iloc[(lenTrain+lenValid):NOP,0]
    model1 = Sequential()
    model1.add(LSTM(256, activation='relu', input_shape=(LagLength,n_features)))
    model1.add(Flatten())
    model1.add(Dense(128, activation='relu'))
    model1.add(Dense(64, activation='relu'))
    model1.add(Dense(32, activation='relu'))
    model1.add(Dense(1,activation='linear'))
    checkpoint_filepath = '/cp.keras'
    cp1=ModelCheckpoint(checkpoint_filepath,save_best_only='True')
    model1.compile(loss=MeanSquaredError(),optimizer=Adam(learning_rate=0.01),metrics=[RootMeanSquaredError(),mean_absolute_percentage_error])
    # fit
    model1.fit(xTrain, yTrain,validation_data=(xValid,yValid), epochs=50, verbose=1)
    yhatNorm=model1.predict(x).flatten().reshape(x.shape[0],1)
    return pd.DataFrame(yhatNorm)

# %%
#Read the Time Series Dataset
Timeseries_Data=pd.read_csv('AQI.csv',header=None)
linear_Data=pd.read_excel('linear.xlsx',header=None)
Residual_Data=Timeseries_Data
LagLength=24
h=1
lt=Timeseries_Data.shape[0]
lenTrain=int(round(lt*0.7))
lenValidation=int(round(lt*0.15))
lenTest=int(lt-lenTrain-lenValidation)
#Compute the Residual Series
for i in range(lt):
    Residual_Data.iloc[i]=Timeseries_Data.iloc[i]-linear_Data.iloc[i]
# NORMALIZE THE DATA
normalizedData=minmaxNorm(Residual_Data,lenTrain+lenValidation);
# Transform the Time Series into Patterns Using Sliding Window
X, y = get_Patterns(normalizedData, LagLength, h)
file1="Accuracy.xlsx"
file2="Forecasts.xlsx"
Forecasts=pd.DataFrame()
Accuracy=pd.DataFrame()
ynorm1=Find_Fitness_LSTM(X,y,lenValidation,lenTest)
ynorm=pd.DataFrame(normalizedData.iloc[0:(LagLength+h-1),0])
ynorm=pd.concat([ynorm, ynorm1], ignore_index=True)
yhat1=minmaxDeNorm(Residual_Data, ynorm, lenTrain+lenValidation)
yhat=yhat1
for i in range(lt):
    yhat.iloc[i]=yhat1.iloc[i]+linear_Data.iloc[i]
Accuracy.loc[0,0],Accuracy.loc[0,1]=findRMSE( Timeseries_Data,yhat,lenTrain+lenValidation)
Accuracy.loc[0,2],Accuracy.loc[0,3]=findMAE( Timeseries_Data,yhat,lenTrain+lenValidation)
Accuracy.to_excel(file1,sheet_name='Accuracy',index=False)
yhat.to_excel(file2,sheet_name='Forecasts',index=False)
print(Accuracy)
# Out:
# Epoch 1/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 137ms/step - loss: 120.1479 - mean_absolute_percentage_error: 784825.1250 - root_mean_squared_error: 9.8433 - val_loss: 0.0868 - val_mean_absolute_percentage_error: 67.9837 - val_root_mean_squared_error: 0.2946
# Epoch 2/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0434 - mean_absolute_percentage_error: 1277686.2500 - root_mean_squared_error: 0.2024 - val_loss: 0.0061 - val_mean_absolute_percentage_error: 14.7722 - val_root_mean_squared_error: 0.0782
# Epoch 3/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0076 - mean_absolute_percentage_error: 612929.3125 - root_mean_squared_error: 0.0860 - val_loss: 0.0037 - val_mean_absolute_percentage_error: 11.6002 - val_root_mean_squared_error: 0.0609
# Epoch 4/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0051 - mean_absolute_percentage_error: 594839.5625 - root_mean_squared_error: 0.0713 - val_loss: 0.0035 - val_mean_absolute_percentage_error: 11.3299 - val_root_mean_squared_error: 0.0588
# Epoch 5/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - loss: 0.0054 - mean_absolute_percentage_error: 445602.5625 - root_mean_squared_error: 0.0731 - val_loss: 0.0034 - val_mean_absolute_percentage_error: 11.7116 - val_root_mean_squared_error: 0.0587
# Epoch 6/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0040 - mean_absolute_percentage_error: 313030.5938 - root_mean_squared_error: 0.0622 - val_loss: 0.0034 - val_mean_absolute_percentage_error: 11.3980 - val_root_mean_squared_error: 0.0585
# Epoch 7/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0060 - mean_absolute_percentage_error: 3396252.7500 - root_mean_squared_error: 0.0774 - val_loss: 0.0036 - val_mean_absolute_percentage_error: 11.3891 - val_root_mean_squared_error: 0.0597
# Epoch 8/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0085 - mean_absolute_percentage_error: 3309140.5000 - root_mean_squared_error: 0.0906 - val_loss: 0.0034 - val_mean_absolute_percentage_error: 11.2544 - val_root_mean_squared_error: 0.0587
# Epoch 9/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0046 - mean_absolute_percentage_error: 321150.3125 - root_mean_squared_error: 0.0669 - val_loss: 0.0035 - val_mean_absolute_percentage_error: 11.2678 - val_root_mean_squared_error: 0.0589
# Epoch 10/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0041 - mean_absolute_percentage_error: 1360799.3750 - root_mean_squared_error: 0.0629 - val_loss: 0.0034 - val_mean_absolute_percentage_error: 11.1873 - val_root_mean_squared_error: 0.0582
# Epoch 11/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - loss: 0.0065 - mean_absolute_percentage_error: 2246464.2500 - root_mean_squared_error: 0.0800 - val_loss: 0.0033 - val_mean_absolute_percentage_error: 11.3050 - val_root_mean_squared_error: 0.0577
# Epoch 12/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0050 - mean_absolute_percentage_error: 1363919.5000 - root_mean_squared_error: 0.0706 - val_loss: 0.0033 - val_mean_absolute_percentage_error: 11.1695 - val_root_mean_squared_error: 0.0573
# Epoch 13/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0053 - mean_absolute_percentage_error: 2280269.7500 - root_mean_squared_error: 0.0727 - val_loss: 0.0038 - val_mean_absolute_percentage_error: 11.6960 - val_root_mean_squared_error: 0.0615
# Epoch 14/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - loss: 0.0053 - mean_absolute_percentage_error: 1273938.6250 - root_mean_squared_error: 0.0718 - val_loss: 0.0032 - val_mean_absolute_percentage_error: 10.7468 - val_root_mean_squared_error: 0.0563
# Epoch 15/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0041 - mean_absolute_percentage_error: 558750.0625 - root_mean_squared_error: 0.0628 - val_loss: 0.0030 - val_mean_absolute_percentage_error: 10.5438 - val_root_mean_squared_error: 0.0549
# Epoch 16/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.0055 - mean_absolute_percentage_error: 3247745.2500 - root_mean_squared_error: 0.0742 - val_loss: 0.0032 - val_mean_absolute_percentage_error: 10.6366 - val_root_mean_squared_error: 0.0562
# Epoch 17/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0060 - mean_absolute_percentage_error: 1015792.3750 - root_mean_squared_error: 0.0769 - val_loss: 0.0030 - val_mean_absolute_percentage_error: 10.2689 - val_root_mean_squared_error: 0.0545
# Epoch 18/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0046 - mean_absolute_percentage_error: 274310.6562 - root_mean_squared_error: 0.0670 - val_loss: 0.0023 - val_mean_absolute_percentage_error: 9.0203 - val_root_mean_squared_error: 0.0479
# Epoch 19/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0039 - mean_absolute_percentage_error: 334536.4688 - root_mean_squared_error: 0.0619 - val_loss: 0.0019 - val_mean_absolute_percentage_error: 8.4467 - val_root_mean_squared_error: 0.0435
# Epoch 20/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - loss: 0.0050 - mean_absolute_percentage_error: 1142100.5000 - root_mean_squared_error: 0.0702 - val_loss: 0.0018 - val_mean_absolute_percentage_error: 8.7310 - val_root_mean_squared_error: 0.0424
# Epoch 21/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0038 - mean_absolute_percentage_error: 357746.8438 - root_mean_squared_error: 0.0611 - val_loss: 0.0013 - val_mean_absolute_percentage_error: 6.5375 - val_root_mean_squared_error: 0.0361
# Epoch 22/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0037 - mean_absolute_percentage_error: 165100.2344 - root_mean_squared_error: 0.0608 - val_loss: 0.0015 - val_mean_absolute_percentage_error: 6.4013 - val_root_mean_squared_error: 0.0391
# Epoch 23/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 0.0019 - mean_absolute_percentage_error: 673785.8125 - root_mean_squared_error: 0.0430 - val_loss: 0.0011 - val_mean_absolute_percentage_error: 5.4835 - val_root_mean_squared_error: 0.0332
# Epoch 24/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0022 - mean_absolute_percentage_error: 583965.8750 - root_mean_squared_error: 0.0461 - val_loss: 0.0015 - val_mean_absolute_percentage_error: 6.4556 - val_root_mean_squared_error: 0.0388
# Epoch 25/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0020 - mean_absolute_percentage_error: 473960.9375 - root_mean_squared_error: 0.0440 - val_loss: 0.0011 - val_mean_absolute_percentage_error: 5.7580 - val_root_mean_squared_error: 0.0335
# Epoch 26/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0013 - mean_absolute_percentage_error: 105609.6094 - root_mean_squared_error: 0.0357 - val_loss: 0.0011 - val_mean_absolute_percentage_error: 6.0067 - val_root_mean_squared_error: 0.0327
# Epoch 27/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0017 - mean_absolute_percentage_error: 1251145.3750 - root_mean_squared_error: 0.0409 - val_loss: 0.0013 - val_mean_absolute_percentage_error: 5.8702 - val_root_mean_squared_error: 0.0366
# Epoch 28/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0032 - mean_absolute_percentage_error: 565634.3125 - root_mean_squared_error: 0.0552 - val_loss: 9.5922e-04 - val_mean_absolute_percentage_error: 5.1941 - val_root_mean_squared_error: 0.0310
# Epoch 29/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0013 - mean_absolute_percentage_error: 77536.1406 - root_mean_squared_error: 0.0356 - val_loss: 0.0031 - val_mean_absolute_percentage_error: 11.4527 - val_root_mean_squared_error: 0.0553
# Epoch 30/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.0027 - mean_absolute_percentage_error: 915562.4375 - root_mean_squared_error: 0.0518 - val_loss: 0.0017 - val_mean_absolute_percentage_error: 7.3447 - val_root_mean_squared_error: 0.0415
# Epoch 31/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 0.0039 - mean_absolute_percentage_error: 305530.0312 - root_mean_squared_error: 0.0611 - val_loss: 0.0015 - val_mean_absolute_percentage_error: 6.3714 - val_root_mean_squared_error: 0.0383
# Epoch 32/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0040 - mean_absolute_percentage_error: 207761.9219 - root_mean_squared_error: 0.0603 - val_loss: 9.2643e-04 - val_mean_absolute_percentage_error: 4.7533 - val_root_mean_squared_error: 0.0304
# Epoch 33/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 0.0022 - mean_absolute_percentage_error: 93042.9766 - root_mean_squared_error: 0.0456 - val_loss: 9.4036e-04 - val_mean_absolute_percentage_error: 5.4841 - val_root_mean_squared_error: 0.0307
# Epoch 34/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0013 - mean_absolute_percentage_error: 74817.5078 - root_mean_squared_error: 0.0352 - val_loss: 0.0024 - val_mean_absolute_percentage_error: 9.9402 - val_root_mean_squared_error: 0.0494
# Epoch 35/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0022 - mean_absolute_percentage_error: 339387.2812 - root_mean_squared_error: 0.0466 - val_loss: 0.0010 - val_mean_absolute_percentage_error: 5.8408 - val_root_mean_squared_error: 0.0317
# Epoch 36/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0013 - mean_absolute_percentage_error: 175874.6875 - root_mean_squared_error: 0.0355 - val_loss: 0.0014 - val_mean_absolute_percentage_error: 6.1839 - val_root_mean_squared_error: 0.0373
# Epoch 37/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 0.0038 - mean_absolute_percentage_error: 136841.2344 - root_mean_squared_error: 0.0589 - val_loss: 9.8691e-04 - val_mean_absolute_percentage_error: 5.7831 - val_root_mean_squared_error: 0.0314
# Epoch 38/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 0.0026 - mean_absolute_percentage_error: 391141.8750 - root_mean_squared_error: 0.0496 - val_loss: 9.0090e-04 - val_mean_absolute_percentage_error: 4.3171 - val_root_mean_squared_error: 0.0300
# Epoch 39/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 9.6833e-04 - mean_absolute_percentage_error: 95426.2500 - root_mean_squared_error: 0.0305 - val_loss: 9.6684e-04 - val_mean_absolute_percentage_error: 5.4404 - val_root_mean_squared_error: 0.0311
# Epoch 40/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0018 - mean_absolute_percentage_error: 429810.4688 - root_mean_squared_error: 0.0402 - val_loss: 8.9546e-04 - val_mean_absolute_percentage_error: 5.1467 - val_root_mean_squared_error: 0.0299
# Epoch 41/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0013 - mean_absolute_percentage_error: 746105.2500 - root_mean_squared_error: 0.0357 - val_loss: 0.0037 - val_mean_absolute_percentage_error: 12.3538 - val_root_mean_squared_error: 0.0606
# Epoch 42/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0052 - mean_absolute_percentage_error: 283276.6250 - root_mean_squared_error: 0.0690 - val_loss: 0.0021 - val_mean_absolute_percentage_error: 9.7288 - val_root_mean_squared_error: 0.0456
# Epoch 43/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 0.0027 - mean_absolute_percentage_error: 250091.7812 - root_mean_squared_error: 0.0512 - val_loss: 0.0021 - val_mean_absolute_percentage_error: 8.4640 - val_root_mean_squared_error: 0.0459
# Epoch 44/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0018 - mean_absolute_percentage_error: 199306.7969 - root_mean_squared_error: 0.0417 - val_loss: 0.0012 - val_mean_absolute_percentage_error: 5.5577 - val_root_mean_squared_error: 0.0346
# Epoch 45/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - loss: 0.0023 - mean_absolute_percentage_error: 227861.3750 - root_mean_squared_error: 0.0471 - val_loss: 9.9271e-04 - val_mean_absolute_percentage_error: 5.5979 - val_root_mean_squared_error: 0.0315
# Epoch 46/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0013 - mean_absolute_percentage_error: 463757.9062 - root_mean_squared_error: 0.0347 - val_loss: 0.0010 - val_mean_absolute_percentage_error: 4.9340 - val_root_mean_squared_error: 0.0322
# Epoch 47/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 0.0027 - mean_absolute_percentage_error: 369174.6562 - root_mean_squared_error: 0.0507 - val_loss: 9.2120e-04 - val_mean_absolute_percentage_error: 5.3790 - val_root_mean_squared_error: 0.0304
# Epoch 48/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 9.1564e-04 - mean_absolute_percentage_error: 81596.2422 - root_mean_squared_error: 0.0289 - val_loss: 9.0322e-04 - val_mean_absolute_percentage_error: 5.2834 - val_root_mean_squared_error: 0.0301
# Epoch 49/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 0.0016 - mean_absolute_percentage_error: 173656.2656 - root_mean_squared_error: 0.0383 - val_loss: 8.8574e-04 - val_mean_absolute_percentage_error: 4.2583 - val_root_mean_squared_error: 0.0298
# Epoch 50/50
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 0.0019 - mean_absolute_percentage_error: 70676.4141 - root_mean_squared_error: 0.0419 - val_loss: 8.8356e-04 - val_mean_absolute_percentage_error: 5.0984 - val_root_mean_squared_error: 0.0297
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step
#            0           1           2          3
# 0  362.51185  353.235493  356.235454  352.69203
